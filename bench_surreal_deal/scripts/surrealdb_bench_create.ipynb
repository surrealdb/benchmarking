# %% [markdown]
#  ## Create the data

# %%
# import required modules
from mimesis.locales import Locale
from mimesis.keys import maybe
from mimesis.schema import Field, Schema
from mimesis.enums import TimestampFormat
from mimesis import Datetime

dt = Datetime()
f = Field(locale=Locale.EN_GB, seed=42)


# Add table definitions

table_definition = {
    "person":{
        "amount":1000
    },
    "product":{
        "amount":1000
    },
    "order":{
        "amount":10000
    },
    "artist":{
        "amount":500
    },
    "review":{
        "amount":2000
    },
    "create":{
        "amount":1000 # should be same as product
    }
}

# Create table data

## person

def person_generator() -> dict:
    first_name = f('first_name')
    last_name = f('last_name')
    return {
        "id":"person:"+f"⟨{f('uuid')}⟩",
        "first_name":first_name,
        "last_name":last_name,
        "name":first_name + " " + last_name,
        "company_name":f("company", key=maybe(None, probability=0.9)),
        "email":f("email"),
        "phone":f("phone_number"),
        "address":{
            "address_line_1":f("street_number")+" "+f("street_name"),
            "address_line_2":f('choice', items=['apt. 10','Suite. 23'], key=maybe(None, probability=0.9)),
            "city":f("city"),
            "country":f('choice', items=['England','Scotland', 'Wales', 'Northern Ireland']),
            "post_code":f("postal_code"),
            "coordinates":[f('latitude'), f('longitude')]
        }
    }

person_schema = Schema(
    schema=person_generator,
    iterations=table_definition['person']['amount']
)
person_data = person_schema.create()

person_id_count = table_definition['person']['amount']-1

print("person data created")

## product

def product_generator() -> dict:
    return {
        "id":"product:"+f"⟨{f('uuid')}⟩",
        "name":' '.join(f('words', quantity=2)),
        "description":' '.join(f('words', quantity=f('integer_number', start=8, end=25))),
        "category":f('choice', items=["oil paint", "watercolor", "acrylic paint", "charcoal", "pencil", "ink", "pastel", "collage", "digital art", "mixed media"]),
        "price":f('price', minimum=500, maximum=25000),
        "currency":f('currency_symbol'),
        "discount":f('float_number', start=0.2, end=0.8, precision=1, key=maybe(None, probability=0.8)),
        "quantity":f('integer_number', start=0, end=20), 
        "image_url":f('stock_image_url')
    }

product_schema = Schema(
    schema=product_generator,
    iterations=table_definition['product']['amount']
)

product_data = product_schema.create()

product_id_count = table_definition['product']['amount']-1

print("product data created")

## order

def order_generator() -> dict:
    person_number = f('integer_number', start=0, end=person_id_count)
    product_number = f('integer_number', start=0, end=product_id_count)
    shipping_address = person_data[person_number]['address']
    order_date = dt.timestamp(TimestampFormat.ISO_8601, start=2023, end=2023)
    return {
        "id":f"order:"+f"⟨{f('uuid')}⟩",
        "in":person_data[person_number]['id'],
        "out":product_data[product_number]['id'],
        "product_name":product_data[product_number]['name'],
        "currency":product_data[product_number]['currency'],
        "discount":product_data[product_number]['discount'],
        "price":product_data[product_number]['price'],
        "quantity":f('integer_number', start=1, end=3),
        "order_date":order_date,
        "shipping_address":shipping_address,
        "payment_method":f('choice', items=['credit card','debit card', 'PayPal']),
        "order_status":f('choice', items=['pending','processing', 'shipped', 'delivered'], key=maybe(None, probability=0.1))
    }

order_schema = Schema(
    schema=order_generator,
    iterations=table_definition['order']['amount']
)

order_data = order_schema.create()

order_id_count = table_definition['order']['amount']-1

print("order data created")

## artist

def artist_generator() -> dict:
    first_name = f("first_name")
    last_name = f("last_name")
    return {
        "id":"artist:"+f"⟨{f('uuid')}⟩",
        "first_name":first_name,
        "last_name":last_name,
        "name":first_name + " " + last_name,
        "company_name":f("company", key=maybe(None, probability=0.5)),
        "email":f("email"),
        "phone":f("phone_number"),
        "address":{
            "address_line_1":f("street_number")+" "+f("street_name"),
            "address_line_2":f('choice', items=['apt. 10','Suite. 23'], key=maybe(None, probability=0.9)),
            "city":f("city"),
            "country":f('choice', items=['England','Scotland', 'Wales', 'Northern Ireland']),
            "post_code":f("postal_code"),
            "coordinates":[f('latitude'), f('longitude')]
        }
    }


artist_schema = Schema(
    schema=artist_generator,
    iterations=table_definition['artist']['amount']
)

artist_data = artist_schema.create()

artist_id_count = table_definition['artist']['amount']-1

print("artist data created")

## review

def review_generator() -> dict:
    return {
        "id":"review:"+f"⟨{f('uuid')}⟩",
        "person":person_data[f('integer_number', start=0, end=person_id_count)]['id'],
        "product":product_data[f('integer_number', start=0, end=product_id_count)]['id'],
        "artist":artist_data[f('integer_number', start=0, end=artist_id_count)]['id'],
        "rating":f('choice', items=[1,2,3,4,5]),
        "review_text":' '.join(f('words', quantity=f('integer_number', start=8, end=50)))
    }

review_schema = Schema(
    schema=review_generator,
    iterations=table_definition['review']['amount']
)

review_data = review_schema.create()

review_id_count = table_definition['review']['amount']-1

print("review data created")

## create
def create_generator() -> dict:
    product_number = f('increment')-1
    artist_number = f('integer_number', start=0, end=artist_id_count)
    created_at = dt.timestamp(TimestampFormat.ISO_8601, start=2023, end=2023)
    return {
        "id":"create:"+f"⟨{f('uuid')}⟩",
        "in":artist_data[artist_number]['id'],
        "out":product_data[product_number]['id'],
        "created_at":created_at,
        "quantity":product_data[product_number]['quantity']
    }

create_schema = Schema(
    schema=create_generator,
    iterations=table_definition['create']['amount']
)

create_data = create_schema.create()

print("create data created")
# Out:
# person data created
# product data created
# order data created
# artist data created
# review data created
# create data created

# %% [markdown]
#  ## Load the data

# %%
from surrealdb import SurrealDB
from uuid import uuid4

db = SurrealDB("ws://localhost:8000/test/test")

db.signin({
    "username": "root",
    "password": "root",
})


def insert_relate_statement(table_data:list[dict]) -> str:
    """
    Inserting data through relate statement
    """

    table_record_id = -1
    for record in table_data:
        table_record_id += 1
        db.query(
    f"RELATE {table_data[table_record_id]['in']} -> {table_data[table_record_id]['id']} -> {table_data[table_record_id]['out']} CONTENT {record};"
            )

# %%
# %%time
db.query(f"INSERT INTO person {person_data}")

# %%
# %%time
db.query(f"INSERT INTO product {product_data}")

# %%
# %%time
insert_relate_statement(order_data)

# %%
# %%time
db.query(f"INSERT INTO artist {artist_data}")

# %%
# %%time
db.query(f"INSERT INTO review {review_data}")

# %%
# %%time
db.query(f"INSERT INTO create {create_data}")
# Out:
# CPU times: user 350 ms, sys: 11 ms, total: 361 ms
# Wall time: 413 ms
# [{'created_at': '2023-02-01T17:11:38.974415',
#   'id': 'create:⟨1d0cbfb3-40b3-485a-96bd-2b4de6e51a3b⟩',
#   'in': 'artist:⟨49958a36-2dce-4b45-9b67-ad35ac314709⟩',
#   'out': 'product:⟨d6b20019-2a87-4b62-a878-d69d15a81d1a⟩',
#   'quantity': 8},
#  {'created_at': '2023-09-16T03:24:45.103881',
#   'id': 'create:⟨3d3e2dcc-b832-4e5e-8dd5-8be476cbe6bd⟩',
#   'in': 'artist:⟨3ce3a733-42ca-4e39-8827-eae45cd82e79⟩',
#   'out': 'product:⟨73ba87fd-3a8c-4f1c-bdb7-5ead7fa718c4⟩',
#   'quantity': 3},
#  {'created_at': '2023-03-23T04:36:35.611386',
#   'id': 'create:⟨75c741c1-454d-4854-a75e-cd4f7e5337ef⟩',
#   'in': 'artist:⟨10627037-0d8a-49de-9bf5-f61976a8c24a⟩',
#   'out': 'product:⟨844860c4-a73c-4883-8b49-39d24471e76d⟩',
#   'quantity': 13},
#  {'created_at': '2023-12-19T18:14:36.801639',
#   'id': 'create:⟨c266f200-a0ec-4a16-a3b5-4176d5a0e80c⟩',
#   'in': 'artist:⟨a02cb703-587d-46a3-bc17-eb907e7b2126⟩',
#   'out': 'product:⟨39f7ca8f-9722-440b-950a-1fd3a540d93b⟩',
#   'quantity': 6},
#  {'created_at': '2023-06-20T06:26:56.622409',
#   'id': 'create:⟨cecaf741-82e7-47e4-b877-0a63eb633c34⟩',
#   'in': 'artist:⟨f9dc3ce3-41ce-475f-b271-5b9b0cb78d99⟩',
#   'out': 'product:⟨0b32c4ef-0737-4bb4-935f-477abaa28579⟩',
#   'quantity': 0},
#  {'created_at': '2023-04-05T17:21:29.611247',
#   'id': 'create:⟨72361004-69fa-498f-affe-5d8b69dfbf8b⟩',
#   'in': 'artist:⟨9d47e627-86f6-40de-bee0-0a341610824a⟩',
#   'out': 'product:⟨91fcb0ae-2815-415b-93c9-c20569137fa5⟩',
#   'quantity': 20},
#  {'created_at': '2023-09-15T05:12:38.360385',
#   'id': 'create:⟨929fe7b0-2d5a-4bb9-8612-cf2b6167411a⟩',
#   'in': 'artist:⟨3a194d02-d086-4838-9992-fb8c1087d1b5⟩',
#   'out': 'product:⟨c563bbd2-9ef9-42d8-bce7-5064edeca444⟩',
#   'quantity': 14},
#  {'created_at': '2023-01-14T21:55:27.281023',
#   'id': 'create:⟨80ad83f6-22c5-4f9a-99a0-dd8b2ff5bcb1⟩',
#   'in': 'artist:⟨86146bab-001c-4bbd-8a3b-5264e8efcd40⟩',
#   'out': 'product:⟨f54f825d-fec4-4fa6-b62a-a10503acd779⟩',
#   'quantity': 0},
#  {'created_at': '2023-02-17T01:02:34.448585',
#   'id': 'create:⟨eab806ee-9223-4e58-977d-8940fb2939fd⟩',
#   'in': 'artist:⟨e53c856f-4984-4328-b004-fcf05c3a6ae7⟩',
#   'out': 'product:⟨3cc063ac-8470-40ff-b332-e79b77283482⟩',
#   'quantity': 10},
#  {'created_at': '2023-03-14T08:24:45.793254',
#   'id': 'create:⟨2114d18a-0b62-4db8-b8d8-a28393a16881⟩',
#   'in': 'artist:⟨0091d52b-9569-415c-9bab-9bc5dca7a470⟩',
#   'out': 'product:⟨246207b8-5ed5-4fba-89ab-c8f44ce9901b⟩',
#   'quantity': 10},
#  {'created_at': '2023-09-28T19:55:37.758629',
#   'id': 'create:⟨c1c0f00c-a4d3-49c5-9025-23cc9ad910ce⟩',
#   'in': 'artist:⟨fd52b2af-d603-4990-9a1e-0a37a9a309c8⟩',
#   'out': 'product:⟨3f217fed-0aca-4ef0-8524-250ecdb49aae⟩',
#   'quantity': 3},
#  {'created_at': '2023-10-21T20:10:59.868827',
#   'id': 'create:⟨c1cf516a-386c-4fde-a696-69e8ab6ed14c⟩',
#   'in': 'artist:⟨9176a4f9-72f8-4dba-91e7-5ca0d56ff7d9⟩',
#   'out': 'product:⟨db6b3866-17d1-446f-8008-bec087f490f1⟩',
#   'quantity': 19},
#  {'created_at': '2023-07-21T07:34:55.796878',
#   'id': 'create:⟨b328b1bc-48c2-4fc7-9ff1-e2dba403a2d7⟩',
#   'in': 'artist:⟨abb5a252-c4af-4e6c-8048-71f42e1d5a88⟩',
#   'out': 'product:⟨8c230290-2173-459c-8727-2e491b26fa78⟩',
#   'quantity': 14},
#  {'created_at': '2023-09-09T09:10:09.386065',
#   'id': 'create:⟨9fac4241-a531-45ca-83a2-3c563a9df5b1⟩',
#   'in': 'artist:⟨994be710-9625-4603-8b95-855ed6d22d7e⟩',
#   'out': 'product:⟨b88d69ce-4df9-408d-a23b-da0344c29757⟩',
#   'quantity': 12},
#  {'created_at': '2023-01-03T10:10:44.226382',
#   'id': 'create:⟨80c8e2d5-0d7c-4504-a633-30d8ff860606⟩',
#   'in': 'artist:⟨7984b76a-75b4-4112-b944-6ed6590f0715⟩',
#   'out': 'product:⟨0a887031-f05d-44fd-96cb-63d74906534c⟩',
#   'quantity': 20},
#  {'created_at': '2023-07-17T17:31:26.784920',
#   'id': 'create:⟨94b3bb80-ecef-4787-97a9-e34a36008b0b⟩',
#   'in': 'artist:⟨76ed79da-cf66-43b5-8411-438ee835c4ed⟩',
#   'out': 'product:⟨24863151-7f10-4d25-9de6-e7ad0c8b420b⟩',
#   'quantity': 2},
#  {'created_at': '2023-06-19T01:15:20.124375',
#   'id': 'create:⟨b4972836-9eae-4f6e-9e13-c306066b00c4⟩',
#   'in': 'artist:⟨a3ae22bb-08f3-4827-b675-8b8643fb3446⟩',
#   'out': 'product:⟨cc4ec3fb-e321-4667-b6fb-dd646b63a03c⟩',
#   'quantity': 9},
#  {'created_at': '2023-11-24T11:33:25.334250',
#   'id': 'create:⟨1236608c-9ef8-4d61-aa99-8ee2395c821c⟩',
#   'in': 'artist:⟨d2d67002-e0ee-46ba-b1f6-781781fb9418⟩',
#   'out': 'product:⟨9fe766ce-c2bc-4671-869a-5db0435dc2e5⟩',
#   'quantity': 3},
#  {'created_at': '2023-09-25T22:28:03.487290',
#   'id': 'create:⟨82ca876e-274a-48ad-91c3-b707fb6fa50a⟩',
#   'in': 'artist:⟨b497b42e-f72e-4a8b-a036-36afc3727083⟩',
#   'out': 'product:⟨96961da4-d61e-4ee4-9a6b-8ea2aed16804⟩',
#   'quantity': 20},
#  {'created_at': '2023-04-01T11:21:41.776113',
#   'id': 'create:⟨db88ad69-3429-4953-88f8-2bd4b2b9a514⟩',
#   'in': 'artist:⟨ff436212-9d78-4d6e-b2b3-9f6db2e2fa93⟩',
#   'out': 'product:⟨dee2dfdf-0f5d-47a6-95be-b017334d0a67⟩',
#   'quantity': 11},
#  {'created_at': '2023-11-28T21:07:55.826498',
#   'id': 'create:⟨af0283bb-0aab-4e93-9ad0-7c442010b80c⟩',
#   'in': 'artist:⟨1a88b4c7-df5b-4dae-8e9e-1bd8f3096b04⟩',
#   'out': 'product:⟨26a6f8ae-7c04-4b2d-96ad-a7995a06f8b4⟩',
#   'quantity': 20},
#  {'created_at': '2023-12-29T13:56:24.448483',
#   'id': 'create:⟨c62eedd6-30c1-40ae-9b86-f19209956aa5⟩',
#   'in': 'artist:⟨e2c4ffa0-7ed7-4a08-b78e-ca658c6e2aca⟩',
#   'out': 'product:⟨a8bb6130-6fb6-43dd-9507-0c1dc2e0df2f⟩',
#   'quantity': 5},
#  {'created_at': '2023-05-22T03:04:14.027724',
#   'id': 'create:⟨15f257af-a057-441a-9c12-0ad9491c0098⟩',
#   'in': 'artist:⟨c9e7a603-0404-4cb9-a2eb-a28ab659e916⟩',
#   'out': 'product:⟨a9d7968f-563b-4289-a380-0bb8e7302a68⟩',
#   'quantity': 5},
#  {'created_at': '2023-03-21T02:40:36.487032',
#   'id': 'create:⟨6afc7cff-9568-4290-ad63-6a6d5fe4c8ff⟩',
#   'in': 'artist:⟨9b0272a0-c1fb-420d-b187-5870c76af43d⟩',
#   'out': 'product:⟨1c1f5e53-d352-4faa-837a-9433bc46f587⟩',
#   'quantity': 20},
#  {'created_at': '2023-01-27T00:50:55.820595',
#   'id': 'create:⟨204f5179-661f-499e-8590-d30dcdd21af2⟩',
#   'in': 'artist:⟨7e53ebe5-ba8c-4a6a-896b-7822e5a8f4bb⟩',
#   'out': 'product:⟨b2a75ecc-3bfb-4243-a634-b0ab9a260d51⟩',
#   'quantity': 10},
#  {'created_at': '2023-05-17T04:10:18.021973',
#   'id': 'create:⟨ed26dee9-7ab4-4ffd-91fa-f7916111adcc⟩',
#   'in': 'artist:⟨529c0a27-c952-4983-9b43-649cd604cb9a⟩',
#   'out': 'product:⟨ce4ab656-1d05-4745-b1b5-dcfe06cf1e0b⟩',
#   'quantity': 1},
#  {'created_at': '2023-07-25T20:11:23.181918',
#   'id': 'create:⟨c5953be9-4916-4de9-94f5-e94ddf070633⟩',
#   'in': 'artist:⟨32dbcf64-c307-4c5a-baa8-74ffb529ad26⟩',
#   'out': 'product:⟨ffb91d81-bfe8-4384-a3e0-dd9ddd9552bf⟩',
#   'quantity': 2},
#  {'created_at': '2023-08-10T03:37:36.370574',
#   'id': 'create:⟨eb481ba1-cf73-4ad0-99a5-bb6b51efbc50⟩',
#   'in': 'artist:⟨f392b9f1-248f-46c8-9306-8c6f0207ab52⟩',
#   'out': 'product:⟨bfe56cc9-9a38-4829-8502-6ce37ae8b64c⟩',
#   'quantity': 18},
#  {'created_at': '2023-10-07T03:21:12.886697',
#   'id': 'create:⟨fe426e9e-8d72-47d8-8285-6f82d4d0ad71⟩',
#   'in': 'artist:⟨22ff9a77-e550-4c48-9aa6-39f35732ca9c⟩',
#   'out': 'product:⟨72172c41-158b-4617-8ba9-a86c045a5788⟩',
#   'quantity': 15},
#  {'created_at': '2023-03-17T19:42:47.340160',
#   'id': 'create:⟨fd5b671e-01ce-47d1-999e-f4b44e5c426c⟩',
#   'in': 'artist:⟨3fe800e4-176d-4c63-870e-31d37cd63c21⟩',
#   'out': 'product:⟨5dbc6820-dd4f-492e-95b3-19aa359752db⟩',
#   'quantity': 20},
#  {'created_at': '2023-11-26T13:11:30.800751',
#   'id': 'create:⟨37d316f8-02ba-4eeb-8999-d43598eb3940⟩',
#   'in': 'artist:⟨54b93e1c-6ba0-44d0-a727-4317ffd7a34a⟩',
#   'out': 'product:⟨3c1e9f2a-d49d-44db-ba71-599996d50134⟩',
#   'quantity': 4},
#  {'created_at': '2023-01-19T07:20:48.344898',
#   'id': 'create:⟨f1a2c110-f82b-4e80-ae1f-d9041fffeb08⟩',
#   'in': 'artist:⟨e76c3ebf-2915-4342-8cb0-ac0f8634622c⟩',
#   'out': 'product:⟨800085ea-1fb1-4334-8b9f-dada49d333db⟩',
#   'quantity': 17},
#  {'created_at': '2023-03-12T06:17:46.337469',
#   'id': 'create:⟨6518bb4e-f0e8-471c-b763-6ae0f1abb269⟩',
#   'in': 'artist:⟨2221ca01-0970-4e5b-8a1a-4ad5e4f8dc2d⟩',
#   'out': 'product:⟨cbde7aa3-a7c8-4946-bbb3-7c6c9c08e1b5⟩',
#   'quantity': 13},
#  {'created_at': '2023-10-24T15:38:55.999571',
#   'id': 'create:⟨f70c82d9-8463-495a-b18f-1b2317a8c7e1⟩',
#   'in': 'artist:⟨defe76b2-f865-499f-ab7a-af1dd65db971⟩',
#   'out': 'product:⟨ae20d2ab-afd3-4d33-9f0b-aedda36f8147⟩',
#   'quantity': 4},
#  {'created_at': '2023-10-16T07:50:50.559979',
#   'id': 'create:⟨d1fe86b4-3fb6-41b8-9070-9b5c23e44348⟩',
#   'in': 'artist:⟨9176a4f9-72f8-4dba-91e7-5ca0d56ff7d9⟩',
#   'out': 'product:⟨4e5c1746-fd77-4467-b289-99f71dc30ab3⟩',
#   'quantity': 1},
#  {'created_at': '2023-04-10T15:29:38.914508',
#   'id': 'create:⟨de271389-5416-447b-95d2-62a1b1bc719e⟩',
#   'in': 'artist:⟨9fc3fd3a-013a-43c9-94ae-edb2d93c9a70⟩',
#   'out': 'product:⟨5a21e018-9ed4-4fa1-a0cc-66ca7bed0673⟩',
#   'quantity': 5},
#  {'created_at': '2023-11-30T03:41:37.328952',
#   'id': 'create:⟨8c3695cd-12bd-4701-9f88-63b5a4053f6f⟩',
#   'in': 'artist:⟨cfb8db45-5ea0-48e5-8365-f837c77248a2⟩',
#   'out': 'product:⟨2d6d535e-da09-4468-8ceb-0b8f664376de⟩',
#   'quantity': 12},
#  {'created_at': '2023-10-12T17:43:36.315665',
#   'id': 'create:⟨55a4fbb3-0005-4c50-890a-f6d9e39d0977⟩',
#   'in': 'artist:⟨3c37be2c-6594-44fc-a965-e68bfee12e37⟩',
#   'out': 'product:⟨ec11240b-1868-4dd4-9b28-23fd90462312⟩',
#   'quantity': 14},
#  {'created_at': '2023-08-10T12:01:32.883120',
#   'id': 'create:⟨5b6acb65-7422-4c9e-9e84-f7453b17d43b⟩',
#   'in': 'artist:⟨5bc87f68-3b7d-4c5c-b97e-301a8638ca06⟩',
#   'out': 'product:⟨ade48f71-e727-44fd-9380-9c5941cca640⟩',
#   'quantity': 17},
#  {'created_at': '2023-12-25T06:05:28.930580',
#   'id': 'create:⟨40e84eab-d47a-4a2d-9e89-a8a7306bdecd⟩',
#   'in': 'artist:⟨e5a46365-f3d5-4593-b0ae-d66b3c7b9050⟩',
#   'out': 'product:⟨adfdac32-c1ab-42e5-9d77-4573d052b525⟩',
#   'quantity': 3},
#  {'created_at': '2023-07-29T01:02:54.627593',
#   'id': 'create:⟨5cba3d72-0188-45ed-aa4a-a3943fe723d0⟩',
#   'in': 'artist:⟨0d78e10c-8bd1-4162-b197-81319a7e5db7⟩',
#   'out': 'product:⟨9a73c752-49df-4322-b6de-e382394843bd⟩',
#   'quantity': 20},
#  {'created_at': '2023-01-07T07:56:55.344651',
#   'id': 'create:⟨649c1a9e-319a-477c-a663-94f56c826de9⟩',
#   'in': 'artist:⟨2c5397a2-c8af-4ad3-89cc-a687118fa32a⟩',
#   'out': 'product:⟨98489324-bd14-4d80-a0e9-ecc5804aac7e⟩',
#   'quantity': 13},
#  {'created_at': '2023-01-22T18:28:05.206981',
#   'id': 'create:⟨7300f043-5a9d-411c-9d21-b0b4abe85eff⟩',
#   'in': 'artist:⟨5691f99c-a519-4389-8a9a-ffb7385c28ed⟩',
#   'out': 'product:⟨a3c78463-4dd2-442d-9d79-ef84e14894e6⟩',
#   'quantity': 8},
#  {'created_at': '2023-11-27T20:15:42.485647',
#   'id': 'create:⟨3f1bccb4-3d79-4b0d-aa27-b86ca65f0efc⟩',
#   'in': 'artist:⟨7a5e2970-5716-47d5-b767-16af4a95f2c1⟩',
#   'out': 'product:⟨ca8e43d1-58f2-466f-91c4-ae04006c7608⟩',
#   'quantity': 16},
#  {'created_at': '2023-12-25T21:54:40.116150',
#   'id': 'create:⟨793e3270-8eea-4258-8682-792e6d2f8ca8⟩',
#   'in': 'artist:⟨2e861e78-ff01-4a0c-8623-7458b3ca5c77⟩',
#   'out': 'product:⟨ab90972a-fb13-4874-8419-93b8e3e568f8⟩',
#   'quantity': 9},
#  {'created_at': '2023-12-13T13:02:54.835574',
#   'id': 'create:⟨ec9f6c54-297c-4c9a-a674-b759d89a284f⟩',
#   'in': 'artist:⟨e83b53b5-5d5e-46bf-9b50-378c8e7f0ae5⟩',
#   'out': 'product:⟨f3393d79-fb2b-49db-9280-32be3361558a⟩',
#   'quantity': 4},
#  {'created_at': '2023-12-28T07:59:39.726271',
#   'id': 'create:⟨d0cd547f-a27c-46ce-97df-372ce915d67e⟩',
#   'in': 'artist:⟨755c3b66-a610-4001-83bf-4ede1e3c3df5⟩',
#   'out': 'product:⟨ddf9ef1b-95e3-4555-bd09-e550b62f1063⟩',
#   'quantity': 17},
#  {'created_at': '2023-04-29T05:14:28.432129',
#   'id': 'create:⟨70720172-6ca8-4d74-b495-18ea58d1281e⟩',
#   'in': 'artist:⟨5691f99c-a519-4389-8a9a-ffb7385c28ed⟩',
#   'out': 'product:⟨199ad437-135c-419c-8b91-2f4a4730c844⟩',
#   'quantity': 19},
#  {'created_at': '2023-05-06T16:51:18.627611',
#   'id': 'create:⟨8f4a4c5d-5cbd-4515-869a-26db1dd7c8c8⟩',
#   'in': 'artist:⟨ab2f7bda-5cb1-408e-bed7-56192e8e1fe8⟩',
#   'out': 'product:⟨5ab5d386-20a4-4f32-bce6-ff5f730b00af⟩',
#   'quantity': 3},
#  {'created_at': '2023-01-27T17:08:36.641967',
#   'id': 'create:⟨d865c28e-e88a-408d-9d92-39e5b940863f⟩',
#   'in': 'artist:⟨4f779011-88ea-42c2-acb7-20e271b7fe40⟩',
#   'out': 'product:⟨c0189b97-e6ea-4c3f-a183-c1b6c2a9c603⟩',
#   'quantity': 9},
#  {'created_at': '2023-09-09T18:47:32.493166',
#   'id': 'create:⟨2e3a078c-be35-4c21-be78-c8b08231985c⟩',
#   'in': 'artist:⟨587b7002-d46f-43df-b08d-8acfd2ee508e⟩',
#   'out': 'product:⟨70a47e41-0072-47e1-a91e-44e45ee82619⟩',
#   'quantity': 18},
#  {'created_at': '2023-10-04T08:40:55.685464',
#   'id': 'create:⟨59816959-26ca-4d15-bfc3-77af7910eed7⟩',
#   'in': 'artist:⟨b8c4fb9a-4982-4db3-ab0e-fb2bb666b88d⟩',
#   'out': 'product:⟨69137c5e-0cda-4d08-ad54-684d00fe4327⟩',
#   'quantity': 15},
#  {'created_at': '2023-06-01T02:53:32.199120',
#   'id': 'create:⟨22235fbe-103d-4df3-969d-d027b119ee33⟩',
#   'in': 'artist:⟨420bc0df-a148-42a1-b14d-a9a53e97db46⟩',
#   'out': 'product:⟨c3951e46-88cb-41f0-8cfd-c05fb9f5a852⟩',
#   'quantity': 17},
#  {'created_at': '2023-09-03T05:02:29.802752',
#   'id': 'create:⟨6daafadd-8c8b-4d37-afaf-75cfaaf5be1e⟩',
#   'in': 'artist:⟨cba8ae8a-d864-48de-9118-995a38ba4c97⟩',
#   'out': 'product:⟨0e995285-7e41-4460-b5dc-a13941158c4a⟩',
#   'quantity': 15},
#  {'created_at': '2023-08-26T08:01:31.743537',
#   'id': 'create:⟨1251541f-55b1-4c3a-b7e9-2672ac0c3c52⟩',
#   'in': 'artist:⟨4d824cf9-ae27-4343-8948-56817b915d65⟩',
#   'out': 'product:⟨212e91d0-4d99-4ec9-89d4-202090e06c68⟩',
#   'quantity': 16},
#  {'created_at': '2023-04-29T15:23:23.815501',
#   'id': 'create:⟨0ca17f02-d581-47b9-baf2-c9f1dec90bab⟩',
#   'in': 'artist:⟨4973a690-efdc-414f-bb36-66ed00e40001⟩',
#   'out': 'product:⟨96887e3b-5415-4431-8b72-10c0a1b62483⟩',
#   'quantity': 17},
#  {'created_at': '2023-08-13T06:56:19.615340',
#   'id': 'create:⟨7d71e913-2c18-4ac1-8d63-79963b487676⟩',
#   'in': 'artist:⟨587b7002-d46f-43df-b08d-8acfd2ee508e⟩',
#   'out': 'product:⟨606b235f-9d07-4cf7-8e5d-8b61a41b2180⟩',
#   'quantity': 12},
#  {'created_at': '2023-04-06T22:17:25.358268',
#   'id': 'create:⟨fa2f10f3-39a0-43b0-977c-f44af3fbbdf3⟩',
#   'in': 'artist:⟨8a6b08ae-379a-4ab8-b057-cd553f25986e⟩',
#   'out': 'product:⟨bb490927-6c02-4016-9369-8909796b32ad⟩',
#   'quantity': 16},
#  {'created_at': '2023-10-12T05:48:21.031017',
#   'id': 'create:⟨a0358803-e536-4110-bcb3-485181b85f34⟩',
#   'in': 'artist:⟨b4e055ae-4df1-4fb9-a407-7bf3967775a1⟩',
#   'out': 'product:⟨44c3077f-7fc8-47a3-973e-71171f983c27⟩',
#   'quantity': 7},
#  {'created_at': '2023-09-21T15:30:41.193925',
#   'id': 'create:⟨4f1197db-7cca-4904-912b-9b2c01745ead⟩',
#   'in': 'artist:⟨f8dcc275-de2e-4518-b576-4a975842d1a0⟩',
#   'out': 'product:⟨77c9b388-9f2a-4ac8-8979-838cdb4157e1⟩',
#   'quantity': 18},
#  {'created_at': '2023-05-28T05:06:56.823001',
#   'id': 'create:⟨a3786ef7-e6c4-48c0-8286-73072ab85c32⟩',
#   'in': 'artist:⟨19165392-85f5-48be-930b-cf571b75c47f⟩',
#   'out': 'product:⟨6ad1b14a-7cd5-4ba4-9eca-89b384271579⟩',
#   'quantity': 7},
#  {'created_at': '2023-10-15T22:50:03.263041',
#   'id': 'create:⟨25f913fb-3480-4acb-92e9-3472df624308⟩',
#   'in': 'artist:⟨7cfc1b19-783f-4c55-88b3-d6bc0fbe788b⟩',
#   'out': 'product:⟨aa4367be-577b-497c-9448-00f2ec710528⟩',
#   'quantity': 20},
#  {'created_at': '2023-03-23T01:05:57.094383',
#   'id': 'create:⟨d5c6eb32-ccca-4a6b-a0b0-7c670168be94⟩',
#   'in': 'artist:⟨4d2b8152-62d9-458a-b3bf-1af2ac4ea426⟩',
#   'out': 'product:⟨14fc8b03-b152-43d6-85a7-88d10a20e6d7⟩',
#   'quantity': 1},
#  {'created_at': '2023-02-11T09:09:26.222622',
#   'id': 'create:⟨8561784f-7dc2-4a1a-bc54-564434b63c11⟩',
#   'in': 'artist:⟨01257917-4723-47ec-af2c-aa772e8be853⟩',
#   'out': 'product:⟨8690f54d-ec4c-49cc-80a9-4971c45970c1⟩',
#   'quantity': 7},
#  {'created_at': '2023-08-31T20:50:38.992050',
#   'id': 'create:⟨ba8e4572-910e-4108-8d47-74e296eb72ee⟩',
#   'in': 'artist:⟨bd825963-dc91-44ce-a713-9c50446578c6⟩',
#   'out': 'product:⟨27bc4804-3c4f-45e0-a84d-e26cfeeda6b9⟩',
#   'quantity': 6},
#  {'created_at': '2023-12-26T00:49:21.455786',
#   'id': 'create:⟨f9cc9bc5-fd7f-4e5b-b275-fcb1e3477886⟩',
#   'in': 'artist:⟨63c9f674-4b10-4024-8acf-814015737752⟩',
#   'out': 'product:⟨a4770227-4e70-4647-ae52-b90288a95d63⟩',
#   'quantity': 18},
#  {'created_at': '2023-03-11T03:27:16.464153',
#   'id': 'create:⟨365df22d-89a7-4088-94d3-c323136b5035⟩',
#   'in': 'artist:⟨793664a7-c4d4-4722-bd72-c773ff92172c⟩',
#   'out': 'product:⟨ab87acc6-8556-4dc9-945d-5ab9c444f576⟩',
#   'quantity': 15},
#  {'created_at': '2023-06-23T21:28:40.893027',
#   'id': 'create:⟨cd8ce24c-6bfd-4905-9f00-f49652e47ca3⟩',
#   'in': 'artist:⟨6a10b4a0-d206-4fd9-9f35-5d811e72c679⟩',
#   'out': 'product:⟨ecf4cdfc-2a92-43fa-a27c-e8f22d77b129⟩',
#   'quantity': 3},
#  {'created_at': '2023-01-04T01:35:46.583126',
#   'id': 'create:⟨8fd9dbf0-4b6b-4998-b838-2c618fff6c21⟩',
#   'in': 'artist:⟨d8c8ebd3-519c-4083-bf45-fe8fc688e644⟩',
#   'out': 'product:⟨d3f96d81-8795-49fa-868a-33589761b276⟩',
#   'quantity': 13},
#  {'created_at': '2023-09-24T18:54:58.620614',
#   'id': 'create:⟨7d5f2b2c-ac57-4b1e-81ff-5f8520769c47⟩',
#   'in': 'artist:⟨42219875-9090-4d4a-ba95-a27e76293a86⟩',
#   'out': 'product:⟨2afdd7e6-f622-4a2e-ad45-1fd4152475c1⟩',
#   'quantity': 1},
#  {'created_at': '2023-01-10T08:52:30.450660',
#   'id': 'create:⟨a403fb1b-502b-44d9-a819-adf3c560f28d⟩',
#   'in': 'artist:⟨6d83f940-ab88-4de0-ac76-ce84573f9981⟩',
#   'out': 'product:⟨bf5d0214-731f-4712-a00e-7070e9ec5a76⟩',
#   'quantity': 10},
#  {'created_at': '2023-03-17T03:25:34.795229',
#   'id': 'create:⟨8988a65c-7c80-4c97-8bb2-519a2d5fd196⟩',
#   'in': 'artist:⟨1e14efae-ad71-4a89-81cd-ec9e15ecdd6d⟩',
#   'out': 'product:⟨0bd5d318-6867-4521-9299-4c14dc636142⟩',
#   'quantity': 6},
#  {'created_at': '2023-02-14T13:38:12.931586',
#   'id': 'create:⟨c9324498-26ac-4d14-b892-932dfb1bb950⟩',
#   'in': 'artist:⟨42219875-9090-4d4a-ba95-a27e76293a86⟩',
#   'out': 'product:⟨d8658408-9be5-4722-8dd4-783b5e02ac24⟩',
#   'quantity': 13},
#  {'created_at': '2023-06-09T23:43:39.072480',
#   'id': 'create:⟨70c6b235-59af-4dca-b219-83f6c5a218a1⟩',
#   'in': 'artist:⟨87ad1f18-8a07-42fd-a929-10f2884c8ce4⟩',
#   'out': 'product:⟨64d88bf5-11b7-4b91-9b17-72925dbed968⟩',
#   'quantity': 7},
#  {'created_at': '2023-04-21T23:28:18.339015',
#   'id': 'create:⟨5db0986c-9cea-400f-955d-f31cd47a0638⟩',
#   'in': 'artist:⟨d27af36d-3be9-447f-9e07-8c30c8ba982e⟩',
#   'out': 'product:⟨aad91404-1115-4e75-9fa2-8326297f22e7⟩',
#   'quantity': 17},
#  {'created_at': '2023-03-16T01:37:15.428623',
#   'id': 'create:⟨0e3e074b-1b71-454d-a221-74599f75d169⟩',
#   'in': 'artist:⟨688a3f6b-aa08-465f-96f3-8129d36c4048⟩',
#   'out': 'product:⟨81825eee-8490-41f0-a97c-31b9629a4387⟩',
#   'quantity': 17},
#  {'created_at': '2023-03-17T07:31:43.285316',
#   'id': 'create:⟨fad5d309-8c1e-4f03-bcab-a1870800dc05⟩',
#   'in': 'artist:⟨1f958fae-2d78-4192-9ead-079abbea5137⟩',
#   'out': 'product:⟨82ac5c39-b1a7-4f9e-bd9a-b9658e1f411d⟩',
#   'quantity': 7},
#  {'created_at': '2023-03-13T20:57:54.452895',
#   'id': 'create:⟨e3d167a9-0b99-43ab-83d4-a0b355609f00⟩',
#   'in': 'artist:⟨c0de50e6-4f94-48fc-aa1d-efeb143cfe20⟩',
#   'out': 'product:⟨ebabb504-e95b-45bc-b0b8-d5efec23e81c⟩',
#   'quantity': 15},
#  {'created_at': '2023-03-06T20:38:01.687102',
#   'id': 'create:⟨fe1e4c26-6dd6-4e5b-963d-da5246177ded⟩',
#   'in': 'artist:⟨cf66da5b-3e9a-4f99-a09b-0e53d5a60424⟩',
#   'out': 'product:⟨895b8bcd-f5ee-41a0-8001-7f9e6553e13c⟩',
#   'quantity': 1},
#  {'created_at': '2023-01-18T07:34:48.639601',
#   'id': 'create:⟨8649b7e3-067d-49e1-ac30-7272fcb1e2e6⟩',
#   'in': 'artist:⟨401b160c-ff9a-48ef-9b34-260ac42fe5ae⟩',
#   'out': 'product:⟨65c133ae-b07d-471d-ad09-fcb6b3dc8718⟩',
#   'quantity': 12},
#  {'created_at': '2023-03-03T12:34:31.866824',
#   'id': 'create:⟨038fe6eb-328c-458d-abc3-a26738e5f115⟩',
#   'in': 'artist:⟨cb42d685-4830-4d30-90bc-68781256afe4⟩',
#   'out': 'product:⟨3036e97a-a23f-40b5-b939-672837b1feab⟩',
#   'quantity': 14},
#  {'created_at': '2023-05-07T11:27:56.824594',
#   'id': 'create:⟨3d5f7415-35a4-4feb-a619-4ea51bedde97⟩',
#   'in': 'artist:⟨3884fbfd-4fe0-4c34-bb3c-b16938f5e389⟩',
#   'out': 'product:⟨7c06d611-62c7-4453-90e7-9a68bec0f1cf⟩',
#   'quantity': 17},
#  {'created_at': '2023-12-27T23:03:12.022120',
#   'id': 'create:⟨3a5917e6-3f1f-42a7-8fb6-0a35c5cf01fc⟩',
#   'in': 'artist:⟨494aedf5-306f-481c-a805-bb2b2507d8f2⟩',
#   'out': 'product:⟨d1b7e05e-a2de-436a-a8b5-3b2273eaa25a⟩',
#   'quantity': 9},
#  {'created_at': '2023-06-23T23:34:36.673573',
#   'id': 'create:⟨aac9767a-125d-4f44-971a-e911b0cb514c⟩',
#   'in': 'artist:⟨0562d7b8-29eb-4b3a-826b-c6592bdf60bf⟩',
#   'out': 'product:⟨a0c99537-a99e-4b39-a2cd-a3f57a15dd33⟩',
#   'quantity': 18},
#  {'created_at': '2023-02-11T16:02:18.521376',
#   'id': 'create:⟨3e80c5c7-60e9-4e67-a166-7faee8104368⟩',
#   'in': 'artist:⟨b546682d-add8-43b2-b6dd-02c92c55eb94⟩',
#   'out': 'product:⟨3146ecaa-fce3-4a63-aa3f-725ca1ed50c7⟩',
#   'quantity': 10},
#  {'created_at': '2023-01-21T09:59:23.936920',
#   'id': 'create:⟨27cc0099-b9b3-4581-bad2-b0ffa6b2e496⟩',
#   'in': 'artist:⟨a8e5f6bf-bbdc-43b3-a3c9-80b24944ba07⟩',
#   'out': 'product:⟨a4079076-9fcb-4d79-a0f0-ee5f6f51cec7⟩',
#   'quantity': 15},
#  {'created_at': '2023-02-26T05:04:26.366905',
#   'id': 'create:⟨233829e5-9395-41de-ae6b-0fcc03f6e276⟩',
#   'in': 'artist:⟨fce0ec77-c378-4bd1-92e3-460c864c922b⟩',
#   'out': 'product:⟨1f97f6ef-bde7-4130-bf97-3597b407be3e⟩',
#   'quantity': 16},
#  {'created_at': '2023-04-21T16:57:24.156386',
#   'id': 'create:⟨469f8177-7cdc-4488-bdbb-b01a3412d8e0⟩',
#   'in': 'artist:⟨e5409dd2-8d1a-4139-9fb3-822eedc22b36⟩',
#   'out': 'product:⟨0913db03-305f-42a2-aefb-712986317253⟩',
#   'quantity': 16},
#  {'created_at': '2023-11-11T01:58:40.878747',
#   'id': 'create:⟨e1b058d9-6de0-4c08-ae36-c58f9f917bcd⟩',
#   'in': 'artist:⟨d4eaa2ee-311a-4c12-b52c-1a21c231746d⟩',
#   'out': 'product:⟨372e23be-3e88-4fe4-aa97-45f24cf1e13c⟩',
#   'quantity': 2},
#  {'created_at': '2023-01-12T09:56:38.917850',
#   'id': 'create:⟨bfd7327f-606c-475c-a03b-1bdcda8071f1⟩',
#   'in': 'artist:⟨2d3880b3-98bf-4b8b-9bea-f77c4b5c96a5⟩',
#   'out': 'product:⟨3adc8658-e5ff-4458-8311-b10d888cd02c⟩',
#   'quantity': 7},
#  {'created_at': '2023-05-19T07:01:46.378099',
#   'id': 'create:⟨de3e4978-d787-4c29-a079-6dde35239407⟩',
#   'in': 'artist:⟨704adbee-d0fc-428a-be47-dc304e0b3cec⟩',
#   'out': 'product:⟨230e65de-2edf-4f58-a049-d98efcd9591c⟩',
#   'quantity': 18},
#  {'created_at': '2023-10-01T00:01:28.125088',
#   'id': 'create:⟨ca248623-4581-456b-9609-189d73a62ab9⟩',
#   'in': 'artist:⟨4aa78b65-35a8-4114-a24b-e821b627959f⟩',
#   'out': 'product:⟨8b6ad6f6-35c2-4e67-8c4d-47b7818011dd⟩',
#   'quantity': 1},
#  {'created_at': '2023-02-24T16:03:33.123233',
#   'id': 'create:⟨962bf48f-5ccc-4752-adbe-1767465580e6⟩',
#   'in': 'artist:⟨fb41d45a-7f78-41e0-83b7-95d7da886174⟩',
#   'out': 'product:⟨a0c432e7-f5eb-4e2a-9ecc-e5577aa28bf9⟩',
#   'quantity': 18},
#  {'created_at': '2023-10-31T22:29:05.064337',
#   'id': 'create:⟨3c548a95-4821-440c-89b6-d6e71be9bb40⟩',
#   'in': 'artist:⟨adc4b180-d98a-456b-a3dc-ae3c92ef8d9b⟩',
#   'out': 'product:⟨7f53c38f-9759-4e69-977f-5ab27211bd3d⟩',
#   'quantity': 8},
#  {'created_at': '2023-01-22T15:09:56.803484',
#   'id': 'create:⟨0be24680-9826-4dd0-b99b-a1d2a60e1d12⟩',
#   'in': 'artist:⟨3df5a467-edc1-4b31-b903-8937029118d6⟩',
#   'out': 'product:⟨2d0d8d33-2133-4e24-95bd-fc283761e7d2⟩',
#   'quantity': 10},
#  {'created_at': '2023-10-03T17:56:33.059639',
#   'id': 'create:⟨cf95b9fe-100d-4842-9d94-4b3bcf68c49c⟩',
#   'in': 'artist:⟨014b93e4-82b1-419e-8360-3122a8187aed⟩',
#   'out': 'product:⟨caaa73b8-1cd8-4ce2-b766-b204cbf30bc9⟩',
#   'quantity': 4},
#  {'created_at': '2023-07-25T05:55:45.002044',
#   'id': 'create:⟨54ffac3c-43c1-436e-82f6-ca7aa9fcb3aa⟩',
#   'in': 'artist:⟨c896858d-3564-4a82-b6d2-5ffc45892cb4⟩',
#   'out': 'product:⟨a13cf95a-5fd1-4c0a-9437-86e351a4e2e7⟩',
#   'quantity': 2},
#  {'created_at': '2023-03-29T19:28:38.014815',
#   'id': 'create:⟨ea1dc47b-335c-4889-99da-a1e352e50705⟩',
#   'in': 'artist:⟨fce0ec77-c378-4bd1-92e3-460c864c922b⟩',
#   'out': 'product:⟨c03c29a7-1a84-48f1-8c4a-2ddc64d90c8e⟩',
#   'quantity': 18},
#  {'created_at': '2023-06-25T14:17:36.519377',
#   'id': 'create:⟨7c08fd65-094f-4b67-b322-4ca3830501eb⟩',
#   'in': 'artist:⟨4055d4e9-e375-4043-973d-5fddb7aac793⟩',
#   'out': 'product:⟨6cd18b36-5e07-4f3f-8539-3927ab43abde⟩',
#   'quantity': 6},
#  {'created_at': '2023-12-30T22:21:42.344588',
#   'id': 'create:⟨01b8d6d6-8136-4ec1-884a-5d36db982a05⟩',
#   'in': 'artist:⟨7db9d365-6f7a-49a5-b3fc-df2dab5a6948⟩',
#   'out': 'product:⟨3d30f6c9-5b9c-4531-a626-104f59db81e5⟩',
#   'quantity': 11},
#  {'created_at': '2023-01-14T20:46:23.088063',
#   'id': 'create:⟨c7dd9d88-47a9-4a02-9f7b-3bfbbb909c88⟩',
#   'in': 'artist:⟨25c5cbdd-a4bd-47a8-b53f-2d327f5682f8⟩',
#   'out': 'product:⟨b9f94bbc-259e-43b5-b8da-eddff0cab0cd⟩',
#   'quantity': 11},
#  {'created_at': '2023-10-14T03:41:01.700727',
#   'id': 'create:⟨a022fdfc-5fe5-4274-b129-3e38f8a43800⟩',
#   'in': 'artist:⟨0d78e10c-8bd1-4162-b197-81319a7e5db7⟩',
#   'out': 'product:⟨23707afc-c906-4a1f-9537-cc062e220b16⟩',
#   'quantity': 17},
#  {'created_at': '2023-03-28T11:25:12.810290',
#   'id': 'create:⟨7a6a450e-bd54-4501-9366-2a5e0cea2ae8⟩',
#   'in': 'artist:⟨4e316a44-9cc9-44a2-888c-b777015ba4af⟩',
#   'out': 'product:⟨4143f83a-fe0d-4c93-be63-942397bd570c⟩',
#   'quantity': 20},
#  {'created_at': '2023-01-08T11:04:47.676196',
#   'id': 'create:⟨c286318e-9e11-4594-93e6-d8e3058c0dc6⟩',
#   'in': 'artist:⟨d003e1a9-b0ab-4cc2-a37f-54c2921c1234⟩',
#   'out': 'product:⟨6823d01f-e90d-4d74-8a50-4d9e98557dfc⟩',
#   'quantity': 17},
#  {'created_at': '2023-12-05T14:22:25.500006',
#   'id': 'create:⟨179d1ecc-6540-4b7f-984d-f5fe4f85cfe3⟩',
#   'in': 'artist:⟨b46f7d81-8630-42df-a7a6-90a68733db6d⟩',
#   'out': 'product:⟨44f1c1e9-e4e7-4dad-bd2f-3ce1cdd78114⟩',
#   'quantity': 3},
#  {'created_at': '2023-09-24T16:55:21.531998',
#   'id': 'create:⟨4d99dbde-45c5-48ee-af93-b2abd8e13d9a⟩',
#   'in': 'artist:⟨69552b06-e5a9-4f57-9ec2-2cea779a9b89⟩',
#   'out': 'product:⟨3fcf0ad4-2492-499e-a44d-4e1f7f2f837d⟩',
#   'quantity': 3},
#  {'created_at': '2023-07-17T06:05:26.041474',
#   'id': 'create:⟨93d2a858-ce0d-47ea-b0d0-a59f20d8a3e2⟩',
#   'in': 'artist:⟨38c867c4-fff7-462d-9baa-85efef54e3a7⟩',
#   'out': 'product:⟨23bf5295-1148-4f8e-a85b-5e34fe7e6989⟩',
#   'quantity': 9},
#  {'created_at': '2023-04-29T11:06:51.219289',
#   'id': 'create:⟨a142c45d-f8c7-42dd-9f3b-a3037cd88e2e⟩',
#   'in': 'artist:⟨135bb9ee-d5dc-4257-9cd7-f5f3d6e44433⟩',
#   'out': 'product:⟨1c74303e-5d2c-4e99-80f2-f33b5ee36464⟩',
#   'quantity': 6},
#  {'created_at': '2023-06-06T19:59:00.516957',
#   'id': 'create:⟨553130c3-a363-49eb-aa03-1947c341d0d3⟩',
#   'in': 'artist:⟨cab87602-d79d-45eb-9f39-03e8b6000fe0⟩',
#   'out': 'product:⟨a352a087-6bd9-4a68-a7fb-e610276ea79e⟩',
#   'quantity': 8},
#  {'created_at': '2023-03-26T21:14:07.573852',
#   'id': 'create:⟨8d9011e3-668d-4ef9-a9d5-c0ad0bd855f9⟩',
#   'in': 'artist:⟨4bcc9736-712f-47e9-b944-a054cafc1504⟩',
#   'out': 'product:⟨c6a31a96-1c25-46a3-bc7d-97a32986d8dd⟩',
#   'quantity': 13},
#  {'created_at': '2023-03-08T06:59:25.099547',
#   'id': 'create:⟨ea12bf33-31c1-42ba-9da4-d147e6d79d3a⟩',
#   'in': 'artist:⟨e5409dd2-8d1a-4139-9fb3-822eedc22b36⟩',
#   'out': 'product:⟨a63ecc3f-0e57-4939-ae04-15202980f1e5⟩',
#   'quantity': 10},
#  {'created_at': '2023-12-28T22:27:06.570636',
#   'id': 'create:⟨d97dff5e-9152-4a37-887c-18b92261f378⟩',
#   'in': 'artist:⟨f9dc3ce3-41ce-475f-b271-5b9b0cb78d99⟩',
#   'out': 'product:⟨f37ced53-1d44-4f88-9aaf-85d4ce4c6222⟩',
#   'quantity': 8},
#  {'created_at': '2023-11-27T15:38:26.637796',
#   'id': 'create:⟨55236487-b68c-437b-b545-5f9519506ade⟩',
#   'in': 'artist:⟨62db9520-560f-4584-8bd0-cace5366e3b2⟩',
#   'out': 'product:⟨89622886-690b-41ad-b12d-dc6ea9f2603c⟩',
#   'quantity': 17},
#  {'created_at': '2023-06-27T15:05:08.764172',
#   'id': 'create:⟨c3e00fdc-d5d9-46f8-8812-91224296d4df⟩',
#   'in': 'artist:⟨fb3d43c5-ec36-4131-ae86-e26d4cd55911⟩',
#   'out': 'product:⟨3ff3a09f-6bf1-4d03-b2c8-df6de0788f82⟩',
#   'quantity': 3},
#  {'created_at': '2023-11-15T10:25:42.306960',
#   'id': 'create:⟨e10ad6d2-a219-4d84-b8a3-c68998a7a049⟩',
#   'in': 'artist:⟨e4a34dcb-b822-4a7b-afe6-30ec614d6c58⟩',
#   'out': 'product:⟨eb406d21-f817-4a73-a8e9-08dc659397c6⟩',
#   'quantity': 4},
#  {'created_at': '2023-05-22T04:10:25.200980',
#   'id': 'create:⟨d3498fc2-cfbd-4d23-87d6-cc55b65af735⟩',
#   'in': 'artist:⟨b562cd3d-4bb2-4398-9c78-c3d2400cc3c0⟩',
#   'out': 'product:⟨9c55227b-b9da-487c-a63a-0b92aa459df4⟩',
#   'quantity': 11},
#  {'created_at': '2023-08-13T18:25:32.291895',
#   'id': 'create:⟨d4566ffc-1f47-414f-aea0-435aa552dbc0⟩',
#   'in': 'artist:⟨dcb1c2dd-2345-44bc-82aa-a4c64032c1ac⟩',
#   'out': 'product:⟨02ceafb3-028f-4717-9cd4-0bb87152d881⟩',
#   'quantity': 4},
#  {'created_at': '2023-05-02T09:37:31.948201',
#   'id': 'create:⟨c8a26a22-6a9b-487c-9048-8c60157f7473⟩',
#   'in': 'artist:⟨4a45423a-9c96-4455-80d2-58c380f82371⟩',
#   'out': 'product:⟨d03d8709-655d-450b-8dde-e96903dcac75⟩',
#   'quantity': 1},
#  {'created_at': '2023-12-22T10:28:14.346335',
#   'id': 'create:⟨9d76f75c-2e4a-4c94-9512-7ad5ea59c6c4⟩',
#   'in': 'artist:⟨4758d2a7-dcad-4e79-b31b-d564df04f5f4⟩',
#   'out': 'product:⟨4f0eb6d1-0481-46d0-88ba-e2a612e9cb26⟩',
#   'quantity': 7},
#  {'created_at': '2023-05-10T23:27:14.995703',
#   'id': 'create:⟨3cde1bd3-ccbb-4ef3-839f-cc726ccfe742⟩',
#   'in': 'artist:⟨39a14711-616c-404c-8823-6aba7b8e20a7⟩',
#   'out': 'product:⟨5681da8a-ca99-4011-aef3-3d8241efd10d⟩',
#   'quantity': 17},
#  {'created_at': '2023-05-12T13:53:25.556927',
#   'id': 'create:⟨e3aa3368-0736-4115-8c1b-2f780c3d000c⟩',
#   'in': 'artist:⟨ab05b27d-48bc-40f4-af66-aef13396831a⟩',
#   'out': 'product:⟨64089fba-40b3-45eb-9830-7998f087a556⟩',
#   'quantity': 4},
#  {'created_at': '2023-06-05T12:05:22.085155',
#   'id': 'create:⟨1fc7432c-1e74-4d8c-bd57-84e7d9151d17⟩',
#   'in': 'artist:⟨494aedf5-306f-481c-a805-bb2b2507d8f2⟩',
#   'out': 'product:⟨2806bae6-ac4a-4880-ab5c-11a63e124eb6⟩',
#   'quantity': 5},
#  {'created_at': '2023-03-29T00:23:25.728937',
#   'id': 'create:⟨17968713-f6ef-4c6a-9ec6-71666fef10a5⟩',
#   'in': 'artist:⟨7a5e2970-5716-47d5-b767-16af4a95f2c1⟩',
#   'out': 'product:⟨a7882a34-8a56-443a-93d3-8ed611b486d8⟩',
#   'quantity': 10},
#  {'created_at': '2023-05-02T03:25:59.581083',
#   'id': 'create:⟨bf6310b3-1db1-47c0-bace-f1185d1c311a⟩',
#   'in': 'artist:⟨1a418397-3c2c-44bb-816c-225e09a0736a⟩',
#   'out': 'product:⟨81e22781-3a79-43a7-beeb-c1fb4591ea76⟩',
#   'quantity': 7},
#  {'created_at': '2023-11-15T16:37:42.186003',
#   'id': 'create:⟨0325ac26-1a33-4642-8ecf-0d0d6780c4ba⟩',
#   'in': 'artist:⟨87fd9832-b691-4ce4-88f8-baf6caad3353⟩',
#   'out': 'product:⟨af1713ad-8f11-425f-aeb2-3f7aa9581a92⟩',
#   'quantity': 3},
#  {'created_at': '2023-02-06T09:39:05.315543',
#   'id': 'create:⟨14e0493f-9121-48ad-acad-30174b3fd88d⟩',
#   'in': 'artist:⟨95c04d6b-b4f3-46a7-a613-95f6027aef9f⟩',
#   'out': 'product:⟨72efffbb-2751-49d0-bb13-ee564ff76656⟩',
#   'quantity': 15},
#  {'created_at': '2023-06-23T13:01:13.601434',
#   'id': 'create:⟨42a3b5f6-ff9b-41ab-a74b-3b4910abe36f⟩',
#   'in': 'artist:⟨244a170a-0d7e-41eb-a141-8a3f0488a524⟩',
#   'out': 'product:⟨48aa3ba0-0b1d-4d4f-8786-1ef2ff0c3c6e⟩',
#   'quantity': 14},
#  {'created_at': '2023-01-12T21:43:28.997578',
#   'id': 'create:⟨4d785833-bd4f-480e-80af-d3662ea623aa⟩',
#   'in': 'artist:⟨4a37b842-f17c-4640-9ddf-b60d0c941b2e⟩',
#   'out': 'product:⟨ec055cf1-1a57-42dc-99cc-ecb403516fae⟩',
#   'quantity': 7},
#  {'created_at': '2023-10-24T10:46:44.522837',
#   'id': 'create:⟨ef1643c7-9791-4f83-8b76-1701d0506e6f⟩',
#   'in': 'artist:⟨bca1d8b3-03ff-4caf-b795-7ca009c8446a⟩',
#   'out': 'product:⟨7af5866c-3d70-48b9-b080-c8c92c001abe⟩',
#   'quantity': 6},
#  {'created_at': '2023-09-21T01:53:35.968259',
#   'id': 'create:⟨8bb57053-3bb2-499b-964f-703826787d71⟩',
#   'in': 'artist:⟨ecf274a4-cd6d-42c0-b35b-35db589b2ea8⟩',
#   'out': 'product:⟨519e13ed-624a-486c-9b50-f46267c49655⟩',
#   'quantity': 2},
#  {'created_at': '2023-05-20T13:40:35.091136',
#   'id': 'create:⟨d336c50a-aab3-447f-b37a-1c53eeeac65b⟩',
#   'in': 'artist:⟨ca959117-2ad0-4a28-b5af-d5876fde9e30⟩',
#   'out': 'product:⟨8fe9982e-9fb8-42d2-8a2a-b825c276da29⟩',
#   'quantity': 16},
#  {'created_at': '2023-12-27T16:25:01.752097',
#   'id': 'create:⟨845094d1-4485-43c3-ac85-d3d3c813ad45⟩',
#   'in': 'artist:⟨4863d913-a9a9-4080-b262-b374029b9fbd⟩',
#   'out': 'product:⟨c655212b-40c7-40aa-a8ca-464a9cc67c10⟩',
#   'quantity': 17},
#  {'created_at': '2023-09-24T16:47:53.696104',
#   'id': 'create:⟨8b298b24-fe89-4d14-86a0-fcb3f2086828⟩',
#   'in': 'artist:⟨cf66da5b-3e9a-4f99-a09b-0e53d5a60424⟩',
#   'out': 'product:⟨6c79ede5-f7a6-4007-bb73-617095d2f2b2⟩',
#   'quantity': 3},
#  {'created_at': '2023-04-29T18:47:56.118767',
#   'id': 'create:⟨71af5f26-60b9-4e29-a61f-951a54309dd7⟩',
#   'in': 'artist:⟨8447f737-942e-496a-b001-e22c91e00240⟩',
#   'out': 'product:⟨b9871e99-cff0-45a7-b465-c0747bbb4947⟩',
#   'quantity': 8},
#  {'created_at': '2023-01-25T15:03:36.394858',
#   'id': 'create:⟨2e26f424-dbb7-4786-a304-038dfefb0aad⟩',
#   'in': 'artist:⟨19a7bc73-bf5f-4b72-a3cc-9745787933e3⟩',
#   'out': 'product:⟨9ae1e203-9546-48a3-8ccd-81a98996f558⟩',
#   'quantity': 13},
#  {'created_at': '2023-02-26T05:03:00.525520',
#   'id': 'create:⟨3b5c5897-80c7-423d-846a-517039395e7f⟩',
#   'in': 'artist:⟨8dcfd91e-c39e-4fcd-be0d-a1ecc061bbd7⟩',
#   'out': 'product:⟨a3d369fa-50d5-4dd8-9866-da3d68f7cdfe⟩',
#   'quantity': 10},
#  {'created_at': '2023-01-17T09:10:38.875005',
#   'id': 'create:⟨758b7727-72c5-4856-bdc1-d4ae8b592d9c⟩',
#   'in': 'artist:⟨acd66155-e4de-4b7d-9f77-cf44d4367041⟩',
#   'out': 'product:⟨c2ae7c1e-c41d-4ae0-b794-e4aa6ae01f5b⟩',
#   'quantity': 16},
#  {'created_at': '2023-08-13T11:40:14.086513',
#   'id': 'create:⟨c7aea172-148d-484e-bf2c-ad7d467e0718⟩',
#   'in': 'artist:⟨8eb0ac2a-6a14-4e40-a3d0-5ada5be52b76⟩',
#   'out': 'product:⟨75819029-1e50-4968-8bd0-777a2eb1f58d⟩',
#   'quantity': 18},
#  {'created_at': '2023-05-28T15:44:31.827821',
#   'id': 'create:⟨e20cbc61-7b36-4ab4-9f17-5f73eabb6f25⟩',
#   'in': 'artist:⟨54b93e1c-6ba0-44d0-a727-4317ffd7a34a⟩',
#   'out': 'product:⟨d26c766f-0b80-4cb8-a55d-221e188af768⟩',
#   'quantity': 13},
#  {'created_at': '2023-09-27T11:14:25.479234',
#   'id': 'create:⟨bc0811f4-b65c-4f53-995e-bcb19aa6a31c⟩',
#   'in': 'artist:⟨e4151138-7ec6-49b0-a80a-9373a17aa84c⟩',
#   'out': 'product:⟨ff3d3796-f4c2-4460-9bf7-d755d1a10482⟩',
#   'quantity': 17},
#  {'created_at': '2023-09-01T18:57:14.736134',
#   'id': 'create:⟨9c83b2f3-f119-4e76-af7a-df504a2bd1a8⟩',
#   'in': 'artist:⟨de78333d-4fbc-4fe6-b190-6a86b1557f3d⟩',
#   'out': 'product:⟨d97c3479-d9eb-4713-ba8b-481cb9032ca7⟩',
#   'quantity': 2},
#  {'created_at': '2023-02-18T14:43:15.561320',
#   'id': 'create:⟨cdd60fb9-a465-46cf-8b59-4f0fe4cb4fd8⟩',
#   'in': 'artist:⟨1995e25f-ca8e-47c0-a3e2-2302ae507178⟩',
#   'out': 'product:⟨56d6544a-4d47-403e-a476-e63b960f3595⟩',
#   'quantity': 3},
#  {'created_at': '2023-11-26T08:30:47.335645',
#   'id': 'create:⟨035be09e-734f-40f5-977b-5820cb8b31d1⟩',
#   'in': 'artist:⟨f9272b04-93ed-4518-87c7-26496d952477⟩',
#   'out': 'product:⟨527093c0-9abf-43a9-86ef-402bea60c594⟩',
#   'quantity': 13},
#  {'created_at': '2023-03-15T15:02:47.279893',
#   'id': 'create:⟨cb039e95-a39e-4a51-b55b-a1ec95d76809⟩',
#   'in': 'artist:⟨4f779011-88ea-42c2-acb7-20e271b7fe40⟩',
#   'out': 'product:⟨7b5c40a3-4193-4b43-9519-8c3acd110c99⟩',
#   'quantity': 9},
#  {'created_at': '2023-01-19T02:33:45.203249',
#   'id': 'create:⟨18459197-030d-4c5b-a7cb-f0cbe697b21b⟩',
#   'in': 'artist:⟨40dae23a-4cd5-42ea-88e3-69f7cf6462d5⟩',
#   'out': 'product:⟨4ee5b6e3-6d17-44a7-8e2b-4006584036ed⟩',
#   'quantity': 13},
#  {'created_at': '2023-02-16T17:05:11.459633',
#   'id': 'create:⟨c05fc347-c749-4811-867f-f3ec2042d162⟩',
#   'in': 'artist:⟨ca959117-2ad0-4a28-b5af-d5876fde9e30⟩',
#   'out': 'product:⟨dccc6619-9867-4bec-973d-4dc29098aa12⟩',
#   'quantity': 5},
#  {'created_at': '2023-07-22T10:42:12.827619',
#   'id': 'create:⟨d2d9643b-eaeb-4800-bbad-bb912d811451⟩',
#   'in': 'artist:⟨37a89bf9-227f-4b1c-902d-3c3f47659510⟩',
#   'out': 'product:⟨f709d745-8a30-4c94-a8cf-834046d99aeb⟩',
#   'quantity': 0},
#  {'created_at': '2023-04-15T09:46:42.850672',
#   'id': 'create:⟨9e7b5729-1ce3-48c4-993c-817da01832a5⟩',
#   'in': 'artist:⟨d27af36d-3be9-447f-9e07-8c30c8ba982e⟩',
#   'out': 'product:⟨8f6bfcc8-30ad-4a5f-b2ea-85023ee4e475⟩',
#   'quantity': 13},
#  {'created_at': '2023-03-25T21:01:33.583040',
#   'id': 'create:⟨29e9e7f2-8949-40a8-8602-444ad1282d14⟩',
#   'in': 'artist:⟨8ff0623e-cc35-4d82-8fe3-ef6d55770234⟩',
#   'out': 'product:⟨d996ad81-62dc-4372-8a48-9add7e441c81⟩',
#   'quantity': 14},
#  {'created_at': '2023-03-11T06:52:17.107042',
#   'id': 'create:⟨b370a459-43d4-49c5-b636-e518c633969c⟩',
#   'in': 'artist:⟨711f9513-29ea-4d1b-b372-5acb51c9ef56⟩',
#   'out': 'product:⟨d6a12657-e5ce-4999-bece-37200fefb99a⟩',
#   'quantity': 5},
#  {'created_at': '2023-11-21T10:06:49.745898',
#   'id': 'create:⟨20185515-3927-49cd-a429-22b432df54f3⟩',
#   'in': 'artist:⟨3abb0749-d663-40a7-8570-1a107eb617c6⟩',
#   'out': 'product:⟨1b041157-d624-4496-aa60-1236d5e2211a⟩',
#   'quantity': 20},
#  {'created_at': '2023-09-13T13:20:16.062902',
#   'id': 'create:⟨73d6d089-8057-4f46-8f85-0090e604500e⟩',
#   'in': 'artist:⟨3561d832-d2dc-4a78-bf3d-17c0025f55f6⟩',
#   'out': 'product:⟨f0b5e2b6-4ef2-466b-afe4-10eaebfb8fd2⟩',
#   'quantity': 7},
#  {'created_at': '2023-01-27T02:14:41.119482',
#   'id': 'create:⟨290c09e3-4a3c-43fd-9782-f5af324146f8⟩',
#   'in': 'artist:⟨95078539-c94e-4a7c-9b99-d731c5b3409f⟩',
#   'out': 'product:⟨7718a513-56ea-4955-a9ec-6c75fbf4bf22⟩',
#   'quantity': 6},
#  {'created_at': '2023-01-18T05:35:58.513569',
#   'id': 'create:⟨3843ce36-de1e-4347-af56-b54a2b3b7c50⟩',
#   'in': 'artist:⟨62b37a74-4026-417f-b89d-3fa58c626f67⟩',
#   'out': 'product:⟨f372136c-560a-4823-937c-3abf4bd9467d⟩',
#   'quantity': 7},
#  {'created_at': '2023-10-18T22:02:43.841362',
#   'id': 'create:⟨d7731725-481c-4015-bd44-8a64240df888⟩',
#   'in': 'artist:⟨534af7bc-cd01-4c92-a45a-cd802543c580⟩',
#   'out': 'product:⟨a26dfd5a-e85a-4fd3-8efb-c5a684cfcab8⟩',
#   'quantity': 2},
#  {'created_at': '2023-08-17T19:49:34.310090',
#   'id': 'create:⟨9d33bde2-4b0f-43a6-b909-f3c86e58cd45⟩',
#   'in': 'artist:⟨534af7bc-cd01-4c92-a45a-cd802543c580⟩',
#   'out': 'product:⟨abca408f-e447-4fac-9d1d-c298110b4a7e⟩',
#   'quantity': 20},
#  {'created_at': '2023-02-26T16:41:41.557357',
#   'id': 'create:⟨8655e6c2-840d-4331-86a1-d7ffa136ba77⟩',
#   'in': 'artist:⟨a0da2818-e3d3-47ca-b532-7c5e876dfedc⟩',
#   'out': 'product:⟨254b4b6f-13be-4cb4-9198-a7a3e12d62dc⟩',
#   'quantity': 12},
#  {'created_at': '2023-05-09T13:51:01.670318',
#   'id': 'create:⟨da71f5b8-8967-4ecb-bf04-4ad05b143c1f⟩',
#   'in': 'artist:⟨c896858d-3564-4a82-b6d2-5ffc45892cb4⟩',
#   'out': 'product:⟨331a065b-a112-43aa-be95-1340227ddf5c⟩',
#   'quantity': 4},
#  {'created_at': '2023-11-13T07:31:42.956875',
#   'id': 'create:⟨36853cbd-a12f-4a1a-879e-4edcd9a0740c⟩',
#   'in': 'artist:⟨fba0470e-2520-4200-8372-b980efbfcf8b⟩',
#   'out': 'product:⟨e2c5f732-10e4-46bc-9b83-d28a4653e063⟩',
#   'quantity': 3},
#  {'created_at': '2023-05-09T17:19:35.933827',
#   'id': 'create:⟨de6d5f6a-72b3-426e-abf7-26824e5d3f7d⟩',
#   'in': 'artist:⟨d003e1a9-b0ab-4cc2-a37f-54c2921c1234⟩',
#   'out': 'product:⟨38849f45-71e6-4f2e-b53f-36b7c43277dd⟩',
#   'quantity': 16},
#  {'created_at': '2023-10-29T19:17:57.254500',
#   'id': 'create:⟨0bf2ebc3-9736-49d2-a165-e7e5ae9ae7ed⟩',
#   'in': 'artist:⟨4de10008-f621-4fa4-8d87-7b676f14284d⟩',
#   'out': 'product:⟨cdb51f8d-f657-4cfd-9268-7ad6c2574894⟩',
#   'quantity': 7},
#  {'created_at': '2023-06-02T12:39:14.956239',
#   'id': 'create:⟨26e938ba-0449-4e86-9d87-bb1e14da5ee8⟩',
#   'in': 'artist:⟨243c5f6f-4fc0-4482-b008-4c797ea7e3a2⟩',
#   'out': 'product:⟨9362ba5e-153f-44e2-908f-4ccd92b885c1⟩',
#   'quantity': 14},
#  {'created_at': '2023-11-04T16:13:08.396531',
#   'id': 'create:⟨17593791-eb81-4588-ae29-e675cd8e3290⟩',
#   'in': 'artist:⟨dd18def6-1669-467f-aa2d-dcc06b60b332⟩',
#   'out': 'product:⟨e8689840-36c4-4bca-b0b6-33de6fc923b1⟩',
#   'quantity': 19},
#  {'created_at': '2023-12-09T06:59:24.438015',
#   'id': 'create:⟨a5bcb8c5-cc8d-4b34-99d6-37541c4640a7⟩',
#   'in': 'artist:⟨e16d1022-41de-42ea-b1fa-4d8e6ff44260⟩',
#   'out': 'product:⟨d108af70-7837-4f99-9ab8-f6daff465c1a⟩',
#   'quantity': 14},
#  {'created_at': '2023-10-04T03:09:20.536988',
#   'id': 'create:⟨63719287-597d-4efe-9586-53d2567827c3⟩',
#   'in': 'artist:⟨1603e5c5-06db-46c7-9bc0-ff23dfc91673⟩',
#   'out': 'product:⟨f46d65d9-2f94-45b2-981d-bc342d2f503c⟩',
#   'quantity': 17},
#  {'created_at': '2023-09-22T15:50:04.924138',
#   'id': 'create:⟨f8e89f69-ae67-4fbf-9444-b6e6f043017c⟩',
#   'in': 'artist:⟨62b37a74-4026-417f-b89d-3fa58c626f67⟩',
#   'out': 'product:⟨dcf3b452-47ff-4ca6-b9e2-3ec6848f2f66⟩',
#   'quantity': 15},
#  {'created_at': '2023-03-08T17:53:55.537812',
#   'id': 'create:⟨dadc9c76-9029-49ba-9a69-01c493bc3153⟩',
#   'in': 'artist:⟨b2e48aba-5e2a-4374-91c9-143a82054959⟩',
#   'out': 'product:⟨fdb4abf9-d0d4-4d63-b75e-f5c2854bb65c⟩',
#   'quantity': 7},
#  {'created_at': '2023-06-21T06:58:49.995127',
#   'id': 'create:⟨a59f71ba-4039-42dc-a52f-e5aa017def3d⟩',
#   'in': 'artist:⟨f8dcc275-de2e-4518-b576-4a975842d1a0⟩',
#   'out': 'product:⟨19df5974-13d9-498c-bf19-f380f2b95a63⟩',
#   'quantity': 16},
#  {'created_at': '2023-08-03T11:51:09.784850',
#   'id': 'create:⟨fcd43e70-0e63-4de0-b213-7ba0531f37da⟩',
#   'in': 'artist:⟨107c2349-761b-436c-a130-601534f060cb⟩',
#   'out': 'product:⟨c5f830a2-a31a-4c48-8d9e-796720982572⟩',
#   'quantity': 8},
#  {'created_at': '2023-02-06T15:57:52.797211',
#   'id': 'create:⟨7691b6f8-fdfd-46dc-b7c7-781e777a6695⟩',
#   'in': 'artist:⟨401b160c-ff9a-48ef-9b34-260ac42fe5ae⟩',
#   'out': 'product:⟨eebcaba5-26b4-4a0b-8149-af19acd70e27⟩',
#   'quantity': 9},
#  {'created_at': '2023-12-12T01:19:59.804086',
#   'id': 'create:⟨330289f5-fe9a-442c-a5c5-eacdb6f8b432⟩',
#   'in': 'artist:⟨a1d4c0e1-dbe3-48b9-b213-397911f687f0⟩',
#   'out': 'product:⟨8cf74743-7fea-415f-9f91-25b4087ecb84⟩',
#   'quantity': 10},
#  {'created_at': '2023-08-10T01:45:27.179943',
#   'id': 'create:⟨b6b9cb97-512b-40d7-abbd-23b266ccc523⟩',
#   'in': 'artist:⟨3eb75354-b010-4612-866a-7f05ed926ac2⟩',
#   'out': 'product:⟨cb4cf2dd-2da4-47be-8e29-7161095a065b⟩',
#   'quantity': 4},
#  {'created_at': '2023-03-13T23:04:53.562639',
#   'id': 'create:⟨c330cbf8-9aff-402f-bc8d-5d05b61d2a58⟩',
#   'in': 'artist:⟨ab2f7bda-5cb1-408e-bed7-56192e8e1fe8⟩',
#   'out': 'product:⟨8b25b97f-f33b-47ed-be0d-04eac6a2a94c⟩',
#   'quantity': 4},
#  {'created_at': '2023-03-04T05:30:32.308917',
#   'id': 'create:⟨58a829a3-1726-410b-8537-96f512f3a58b⟩',
#   'in': 'artist:⟨55f6f009-990e-4e1f-a381-176ea8c36b70⟩',
#   'out': 'product:⟨2721d6dd-1b96-40a6-8882-65552eed696f⟩',
#   'quantity': 13},
#  {'created_at': '2023-07-05T11:19:34.330336',
#   'id': 'create:⟨dd58c6ed-d969-46f6-b0fc-15a499955b31⟩',
#   'in': 'artist:⟨9254795f-1a95-45bd-a7eb-f0285c4513f3⟩',
#   'out': 'product:⟨cfe97c29-1eef-4c2e-b00d-2f4d686d0b81⟩',
#   'quantity': 13},
#  {'created_at': '2023-07-30T03:00:04.426128',
#   'id': 'create:⟨984aa6f7-951e-4674-bdb5-bbed36bb439f⟩',
#   'in': 'artist:⟨63c9f674-4b10-4024-8acf-814015737752⟩',
#   'out': 'product:⟨5b942716-2551-4e22-b740-b21abf5aeffd⟩',
#   'quantity': 13},
#  {'created_at': '2023-09-04T04:37:43.039265',
#   'id': 'create:⟨ca1dfe93-a340-42c4-90fd-aa5450ab8586⟩',
#   'in': 'artist:⟨18cec0e0-2fb8-44cb-8c01-cab411db2e69⟩',
#   'out': 'product:⟨8121466e-d8a6-4f2a-b484-1d9ff04d6459⟩',
#   'quantity': 18},
#  {'created_at': '2023-10-22T19:34:01.861080',
#   'id': 'create:⟨483c4996-fd1f-4196-802f-eb07f1f59484⟩',
#   'in': 'artist:⟨64e44283-e367-417b-a5a5-fb91e99d3bb7⟩',
#   'out': 'product:⟨c998a109-404c-4e33-9249-119179e2b01a⟩',
#   'quantity': 18},
#  {'created_at': '2023-06-03T03:21:44.835961',
#   'id': 'create:⟨bbc2602d-4c33-47d6-85a2-989607084ec8⟩',
#   'in': 'artist:⟨e483ebf9-421f-4015-ab12-243520940cd7⟩',
#   'out': 'product:⟨52fa8552-e297-4286-97c9-c53ce61d291d⟩',
#   'quantity': 11},
#  {'created_at': '2023-12-17T21:10:06.587474',
#   'id': 'create:⟨c27cc6cf-5e83-441a-8269-b831b0ec621d⟩',
#   'in': 'artist:⟨4a45423a-9c96-4455-80d2-58c380f82371⟩',
#   'out': 'product:⟨4350d2a8-087d-422d-af0b-58c1fccb6fe6⟩',
#   'quantity': 13},
#  {'created_at': '2023-01-23T18:15:01.489577',
#   'id': 'create:⟨490b05d1-3165-47c0-bc32-1dafe29e7697⟩',
#   'in': 'artist:⟨4a81c41d-fcc9-4188-8d6d-a56524a92c34⟩',
#   'out': 'product:⟨d01639c8-87c0-42e4-a64f-b221c754135e⟩',
#   'quantity': 17},
#  {'created_at': '2023-09-13T11:53:37.489922',
#   'id': 'create:⟨3b368699-37ca-4e1d-993d-01cd1c1c4ffc⟩',
#   'in': 'artist:⟨b1aa7b0e-0be9-489b-b9c9-b8874cee2fb9⟩',
#   'out': 'product:⟨928a866b-a495-43a1-990b-a78537e82f2a⟩',
#   'quantity': 8},
#  {'created_at': '2023-02-26T11:53:01.699568',
#   'id': 'create:⟨07ee388b-32b6-45a8-add2-84e7a269ff53⟩',
#   'in': 'artist:⟨ced81406-8d47-4b0e-bb29-682d76e9ba3b⟩',
#   'out': 'product:⟨f797fc2c-bfe3-4220-82c7-d4728fa5cf1d⟩',
#   'quantity': 12},
#  {'created_at': '2023-07-24T15:13:59.881439',
#   'id': 'create:⟨2dcdb9c5-52c9-43d7-b976-4fcd7393322b⟩',
#   'in': 'artist:⟨3abb0749-d663-40a7-8570-1a107eb617c6⟩',
#   'out': 'product:⟨06e19ad2-2628-4515-8ff0-3f515e41c434⟩',
#   'quantity': 12},
#  {'created_at': '2023-05-27T21:27:18.920905',
#   'id': 'create:⟨f18d2781-5b0a-46d4-b4f2-5c10077e4c71⟩',
#   'in': 'artist:⟨990b9c1f-538f-4569-bbe0-dab6255f8120⟩',
#   'out': 'product:⟨903f390c-64a4-4ab9-838d-51320236ad49⟩',
#   'quantity': 4},
#  {'created_at': '2023-08-31T05:26:49.885938',
#   'id': 'create:⟨bc220fdf-c9d4-4e5d-a865-89d66dcd681c⟩',
#   'in': 'artist:⟨a873a312-c544-4af3-9898-336080d56df0⟩',
#   'out': 'product:⟨541f4415-5e07-401f-920b-54b798852704⟩',
#   'quantity': 12},
#  {'created_at': '2023-12-18T10:03:05.787409',
#   'id': 'create:⟨bb1c28a0-0da1-4a7a-a1d9-3aebeace6a38⟩',
#   'in': 'artist:⟨64b43c2e-3463-404e-8877-71861b9b5c13⟩',
#   'out': 'product:⟨b511fdfb-12c8-41ef-9db2-a49a402abf04⟩',
#   'quantity': 13},
#  {'created_at': '2023-09-18T11:04:31.859663',
#   'id': 'create:⟨c6167fc5-158b-45ae-91b5-01c2131fd4c3⟩',
#   'in': 'artist:⟨f5ac7a78-223c-4170-881e-f715cda7814c⟩',
#   'out': 'product:⟨dadbf7fd-462d-42e1-b81c-dee99e7612f4⟩',
#   'quantity': 5},
#  {'created_at': '2023-07-26T12:33:53.481037',
#   'id': 'create:⟨84091569-26a8-476e-9f37-63eedee848ee⟩',
#   'in': 'artist:⟨54d3bbf3-b1eb-4c97-98bf-2839a75088f9⟩',
#   'out': 'product:⟨29147ec1-7011-41c7-a7e0-756186e976a8⟩',
#   'quantity': 10},
#  {'created_at': '2023-04-16T22:39:03.678978',
#   'id': 'create:⟨e658828f-0d21-4a45-977b-d080a810c9c1⟩',
#   'in': 'artist:⟨0bf3dfd5-5832-440a-a94a-13e35d35e21a⟩',
#   'out': 'product:⟨bd28d02e-0252-4faa-a623-93fef8629e30⟩',
#   'quantity': 10},
#  {'created_at': '2023-02-19T20:36:29.744145',
#   'id': 'create:⟨11d19db3-d1eb-4d1f-9e81-ce5b02f7400b⟩',
#   'in': 'artist:⟨0aec4d4e-8ab4-4af0-a279-57e9876a69f2⟩',
#   'out': 'product:⟨cb3d0994-9370-491d-a2df-08f4915ebf89⟩',
#   'quantity': 13},
#  {'created_at': '2023-08-23T15:31:57.787201',
#   'id': 'create:⟨b374f178-af8e-4647-bf49-53a985cbec4f⟩',
#   'in': 'artist:⟨de78333d-4fbc-4fe6-b190-6a86b1557f3d⟩',
#   'out': 'product:⟨3d9db7c5-53d2-49ac-b960-d0bc7b345086⟩',
#   'quantity': 15},
#  {'created_at': '2023-12-27T19:16:32.098573',
#   'id': 'create:⟨2f7dbdaf-1366-4c08-9c62-ccd2068af163⟩',
#   'in': 'artist:⟨76ed79da-cf66-43b5-8411-438ee835c4ed⟩',
#   'out': 'product:⟨6b9dbfae-5b49-4058-b289-292e63c9d8f6⟩',
#   'quantity': 1},
#  {'created_at': '2023-07-09T19:31:31.736450',
#   'id': 'create:⟨37fb0044-72f2-4589-aa58-2f2922788029⟩',
#   'in': 'artist:⟨ff31afd3-ae71-4b30-babc-a6542e123a66⟩',
#   'out': 'product:⟨5f096ff5-475e-4508-974f-fde8d15c25af⟩',
#   'quantity': 2},
#  {'created_at': '2023-10-16T16:23:41.088907',
#   'id': 'create:⟨5f5c9071-5a80-41ed-b261-f1ce59a9f904⟩',
#   'in': 'artist:⟨54e385e4-03ed-45f9-a7f7-3141e88ec6ce⟩',
#   'out': 'product:⟨cc231515-2095-4a5f-b56c-f0ccaed36f21⟩',
#   'quantity': 7},
#  {'created_at': '2023-10-01T18:30:02.985855',
#   'id': 'create:⟨09f704e1-640d-40e8-b73e-b7edbd7ad964⟩',
#   'in': 'artist:⟨9fa30011-7a1d-4876-9f84-17ad4cbff5af⟩',
#   'out': 'product:⟨20989016-fc45-49dc-a289-6e6a92428071⟩',
#   'quantity': 19},
#  {'created_at': '2023-04-06T21:50:54.295498',
#   'id': 'create:⟨497c8e0c-cf6f-4d2c-85bb-71a00a91dac8⟩',
#   'in': 'artist:⟨1f958fae-2d78-4192-9ead-079abbea5137⟩',
#   'out': 'product:⟨39983daa-36b1-46e5-a298-4a3fe550fb4b⟩',
#   'quantity': 15},
#  {'created_at': '2023-05-08T14:39:19.497066',
#   'id': 'create:⟨1f9a78d2-cae2-455a-9d19-7ba096a3d0ef⟩',
#   'in': 'artist:⟨3ee0fe4e-f3c2-4ef6-b16e-7f86b2df07c9⟩',
#   'out': 'product:⟨d7d0ec66-cbe5-468f-83f4-d12a3f5c81f5⟩',
#   'quantity': 6},
#  {'created_at': '2023-11-29T07:04:21.009724',
#   'id': 'create:⟨61fd33cc-9c8f-453c-bb30-293f6cb8fd98⟩',
#   'in': 'artist:⟨793664a7-c4d4-4722-bd72-c773ff92172c⟩',
#   'out': 'product:⟨68cea108-96d8-4329-bae2-d19b8a981f3b⟩',
#   'quantity': 11},
#  {'created_at': '2023-12-10T06:56:50.995195',
#   'id': 'create:⟨f93cf14e-fce8-4857-91f2-d5e23678c4e8⟩',
#   'in': 'artist:⟨3e890b35-574e-4a2e-94f3-19dd7d5beac8⟩',
#   'out': 'product:⟨4bc9ae51-1575-45a7-b510-b6254d15e708⟩',
#   'quantity': 3},
#  {'created_at': '2023-07-03T11:31:45.866292',
#   'id': 'create:⟨76b55fd0-3f6b-4e0d-afa5-969c985155ee⟩',
#   'in': 'artist:⟨529c0a27-c952-4983-9b43-649cd604cb9a⟩',
#   'out': 'product:⟨a09ebb25-81a4-4658-a231-2eeecf2996db⟩',
#   'quantity': 3},
#  {'created_at': '2023-05-01T18:54:42.364366',
#   'id': 'create:⟨c5d7eeed-2d1b-44a4-85c3-77cacd4fc78f⟩',
#   'in': 'artist:⟨0dfc239c-7989-452b-b02b-d5d5e4fa864f⟩',
# ...
#   'out': 'product:⟨9f7bbd3f-bc0e-4e8d-9b4c-d61be26f5f65⟩',
#   'quantity': 1},
#  {'created_at': '2023-08-13T21:03:33.829002',
#   'id': 'create:⟨70a2a404-3fda-4543-b19f-759234776c9a⟩',
#   'in': 'artist:⟨b8c4fb9a-4982-4db3-ab0e-fb2bb666b88d⟩',
#   'out': 'product:⟨0cae7109-5dbc-4b2e-bc56-11c9b229214d⟩',
#   'quantity': 2},
#  {'created_at': '2023-09-20T17:54:06.781097',
#   'id': 'create:⟨4eb1683e-dfdc-40f5-b9ad-efb8fd775338⟩',
#   'in': 'artist:⟨dca07405-f96e-45ee-b6d2-a8067702b72d⟩',
#   'out': 'product:⟨695bfec9-146a-4798-9750-d29b624d17f2⟩',
#   'quantity': 3},
#  {'created_at': '2023-11-11T03:08:14.079918',
#   'id': 'create:⟨cfecdd11-470f-493d-b470-344482ee21c2⟩',
#   'in': 'artist:⟨20bc7785-ae20-4b7d-996d-b6846567d931⟩',
#   'out': 'product:⟨57d2f529-09fb-46e0-9651-540af96ecbd6⟩',
#   'quantity': 18},
#  {'created_at': '2023-09-06T04:19:20.504237',
#   'id': 'create:⟨b67e2b65-87fb-413c-a06d-f70030d56e0d⟩',
#   'in': 'artist:⟨8eb0247b-3457-439d-97cb-e9a7f745daf4⟩',
#   'out': 'product:⟨528b0a62-f184-4ac1-ab17-33f893217abd⟩',
#   'quantity': 19},
#  {'created_at': '2023-04-26T21:40:03.282090',
#   'id': 'create:⟨621586a8-5d83-4dd4-bc68-1a7ff04d2a54⟩',
#   'in': 'artist:⟨9f849830-941d-439c-bd4d-fa03c2505109⟩',
#   'out': 'product:⟨2784558e-80e6-4d91-9621-fa029fff308e⟩',
#   'quantity': 4},
#  {'created_at': '2023-12-04T10:14:49.767595',
#   'id': 'create:⟨06f5083d-927b-44ac-b4e8-0b37faace1bd⟩',
#   'in': 'artist:⟨00ff0ec6-8ba5-46d3-931d-5e04587402d0⟩',
#   'out': 'product:⟨81614c29-71a1-4752-be4b-4a127a75f9bd⟩',
#   'quantity': 1},
#  {'created_at': '2023-06-11T03:04:26.326854',
#   'id': 'create:⟨dea8f32f-64e4-42d0-9a41-d652bae4cf78⟩',
#   'in': 'artist:⟨d27af36d-3be9-447f-9e07-8c30c8ba982e⟩',
#   'out': 'product:⟨74b3e289-cd65-49e1-8865-4d72c082393a⟩',
#   'quantity': 19},
#  {'created_at': '2023-02-15T12:59:16.997411',
#   'id': 'create:⟨456f1c5c-37a6-4333-8724-a80f075a9132⟩',
#   'in': 'artist:⟨1c2b7be9-0978-4b2c-aa5f-b6c5b476d470⟩',
#   'out': 'product:⟨457f3d73-025b-48c6-b2b9-34a6bf73a135⟩',
#   'quantity': 9},
#  {'created_at': '2023-06-30T13:17:59.225274',
#   'id': 'create:⟨9a0f3025-aafc-4a52-b84f-29de86b80e1f⟩',
#   'in': 'artist:⟨74bfd06a-a807-4eda-b9e9-be1ce1734539⟩',
#   'out': 'product:⟨11b133be-2f5a-46f4-9c2d-e5b9bfe2e893⟩',
#   'quantity': 16},
#  {'created_at': '2023-02-21T16:58:18.003650',
#   'id': 'create:⟨eab30c3c-5fb1-4bdb-aad2-cb4576152db2⟩',
#   'in': 'artist:⟨b98c4170-0cbb-4285-b80d-034863ae5aad⟩',
#   'out': 'product:⟨dd1f8e86-f67f-42f0-b1ad-1f8bb77df18f⟩',
#   'quantity': 13},
#  {'created_at': '2023-01-03T03:42:11.364535',
#   'id': 'create:⟨d17f5387-ad2c-4c96-be9d-09bdb918a320⟩',
#   'in': 'artist:⟨0d974294-981a-4c1d-ac35-8e2387f664e8⟩',
#   'out': 'product:⟨782c7df1-919a-4d6c-a41a-2f128720deea⟩',
#   'quantity': 20},
#  {'created_at': '2023-03-11T23:10:57.041585',
#   'id': 'create:⟨5ddfd64b-3975-4c6f-add9-16022850d665⟩',
#   'in': 'artist:⟨7984b76a-75b4-4112-b944-6ed6590f0715⟩',
#   'out': 'product:⟨211bb440-6006-41ee-ba5b-956a48b72c49⟩',
#   'quantity': 4},
#  {'created_at': '2023-12-11T18:00:03.473562',
#   'id': 'create:⟨113ad2d5-0a32-4f96-8cb3-e26fb49ab42a⟩',
#   'in': 'artist:⟨994be710-9625-4603-8b95-855ed6d22d7e⟩',
#   'out': 'product:⟨318c5224-116f-4e34-9a4b-6e657f5422e6⟩',
#   'quantity': 10},
#  {'created_at': '2023-01-08T17:01:58.291562',
#   'id': 'create:⟨618e4e2b-9f27-4e5d-b313-a3a9e0759eb4⟩',
#   'in': 'artist:⟨32dbcf64-c307-4c5a-baa8-74ffb529ad26⟩',
#   'out': 'product:⟨2f8d04c8-dac6-4a7e-89ff-124e51d0ecf8⟩',
#   'quantity': 12},
#  {'created_at': '2023-01-21T18:22:52.077308',
#   'id': 'create:⟨2025b693-e985-4d7f-aa2a-6c9f34eab67e⟩',
#   'in': 'artist:⟨9d0bc731-0618-48af-a5f2-e629df2226e8⟩',
#   'out': 'product:⟨2f065115-f2f8-428e-a19c-bafa681bd07d⟩',
#   'quantity': 20},
#  {'created_at': '2023-01-24T02:13:13.361036',
#   'id': 'create:⟨027462b1-3fa9-45ba-8d09-77c825689a70⟩',
#   'in': 'artist:⟨1398a693-d369-4832-b4e9-4e06ecd9e068⟩',
#   'out': 'product:⟨abe9611f-25ac-46b5-9435-f0d5652bfcce⟩',
#   'quantity': 12},
#  {'created_at': '2023-01-11T06:13:06.671689',
#   'id': 'create:⟨84a58874-9850-46a4-848e-07277a97ce7d⟩',
#   'in': 'artist:⟨4a37b842-f17c-4640-9ddf-b60d0c941b2e⟩',
#   'out': 'product:⟨ab544735-e9c1-4fa7-9260-83af315e4cde⟩',
#   'quantity': 2},
#  {'created_at': '2023-12-05T18:37:34.873140',
#   'id': 'create:⟨e1032e55-9f55-4087-8f26-d76d072a3453⟩',
#   'in': 'artist:⟨060220b3-7cda-42e9-a25a-a04eecb1e63f⟩',
#   'out': 'product:⟨adf0029c-648f-48c9-a3f4-636a12be5753⟩',
#   'quantity': 8},
#  {'created_at': '2023-03-18T14:02:32.217284',
#   'id': 'create:⟨b2387925-4c3b-4fe0-824d-a0ad31c60d92⟩',
#   'in': 'artist:⟨6c18dd48-806a-4ebe-a266-ac056258b349⟩',
#   'out': 'product:⟨ae8d0d35-03c9-4e7d-9624-331cd49e612a⟩',
#   'quantity': 15},
#  {'created_at': '2023-09-17T02:11:05.279690',
#   'id': 'create:⟨30c29c3f-cf23-4d43-90fa-dbed9303c4c0⟩',
#   'in': 'artist:⟨2ce4e38c-3c01-4c1e-bf2e-b5612e09a350⟩',
#   'out': 'product:⟨3c45b7c0-0a47-4048-9dc9-41f2d16fb121⟩',
#   'quantity': 2},
#  {'created_at': '2023-01-20T16:21:53.371838',
#   'id': 'create:⟨e5e0ced2-03b1-485e-b6f2-31d942950325⟩',
#   'in': 'artist:⟨420bc0df-a148-42a1-b14d-a9a53e97db46⟩',
#   'out': 'product:⟨acbe308d-0806-441b-af58-72d889335aa7⟩',
#   'quantity': 11},
#  {'created_at': '2023-02-20T00:25:22.599325',
#   'id': 'create:⟨bf349ecd-fbf2-4ebd-b33b-1cff57f8f431⟩',
#   'in': 'artist:⟨5c59c203-0565-4576-b834-2100c8e0c46e⟩',
#   'out': 'product:⟨9d78762a-93a8-4b48-a1c4-95d08ea49909⟩',
#   'quantity': 12},
#  {'created_at': '2023-02-23T02:19:51.596822',
#   'id': 'create:⟨bf64bcda-3675-46f3-9638-33a6e46a3ad2⟩',
#   'in': 'artist:⟨1e14efae-ad71-4a89-81cd-ec9e15ecdd6d⟩',
#   'out': 'product:⟨2b9c793a-7198-4387-a2d6-d286672e30da⟩',
#   'quantity': 6},
#  {'created_at': '2023-12-31T21:22:25.601964',
#   'id': 'create:⟨85c4e1ad-85e2-4c1f-8d94-d3cdc22b105c⟩',
#   'in': 'artist:⟨857b3806-934c-40db-9e3e-e9418dc5deb4⟩',
#   'out': 'product:⟨9b08dda0-8ae8-4418-a0c8-d0a08fd77f7c⟩',
#   'quantity': 9},
#  {'created_at': '2023-06-13T12:57:00.620968',
#   'id': 'create:⟨3bb90dcc-41ba-42cd-8758-f9b20eb2adf6⟩',
#   'in': 'artist:⟨29a30de1-5ee7-4315-b2bd-0d402d44a9d5⟩',
#   'out': 'product:⟨ef81a231-6afa-48a0-9e1d-3e2bd1e2cfed⟩',
#   'quantity': 4},
#  {'created_at': '2023-07-28T08:48:21.277486',
#   'id': 'create:⟨faec2cc1-422e-420c-ae2e-a1f4c9ba13c6⟩',
#   'in': 'artist:⟨7984b76a-75b4-4112-b944-6ed6590f0715⟩',
#   'out': 'product:⟨01f7aecd-9608-4d29-9a40-17012307a1de⟩',
#   'quantity': 1},
#  {'created_at': '2023-05-24T16:27:17.486127',
#   'id': 'create:⟨66ce7b1f-74ff-42c4-8fab-e87a0ff49706⟩',
#   'in': 'artist:⟨26d96a3e-51fb-4ffa-a5b3-4492c67faee5⟩',
#   'out': 'product:⟨073ae8f8-6b23-42f3-bdb1-4615bca9a77d⟩',
#   'quantity': 14},
#  {'created_at': '2023-12-18T19:38:38.081346',
#   'id': 'create:⟨e9f423ed-6082-466a-94f2-5beb047111a3⟩',
#   'in': 'artist:⟨84a9669b-9046-4b90-9aa5-c77ca67b6c00⟩',
#   'out': 'product:⟨1cddb28d-8b86-4bec-8c6f-41d253481186⟩',
#   'quantity': 5},
#  {'created_at': '2023-03-03T22:59:58.410927',
#   'id': 'create:⟨5a369f57-e572-4c47-8f9c-956eb180bee1⟩',
#   'in': 'artist:⟨55f6f009-990e-4e1f-a381-176ea8c36b70⟩',
#   'out': 'product:⟨9a76686d-9775-4ad8-b2ac-7456bba11f8e⟩',
#   'quantity': 13},
#  {'created_at': '2023-11-17T13:57:58.057712',
#   'id': 'create:⟨3a5aad1d-c923-4123-9428-df65eaacc27a⟩',
#   'in': 'artist:⟨8e94eeec-e713-440f-beb4-4b75f5fadacd⟩',
#   'out': 'product:⟨a874a9b1-d827-4c05-a15f-bd6da3455ac3⟩',
#   'quantity': 4},
#  {'created_at': '2023-03-24T11:24:26.293534',
#   'id': 'create:⟨93cff287-cb3f-4514-a4f5-99a753ad21d5⟩',
#   'in': 'artist:⟨d8c8ebd3-519c-4083-bf45-fe8fc688e644⟩',
#   'out': 'product:⟨7e14dde6-de1e-41ff-be7d-30629dcccd98⟩',
#   'quantity': 8},
#  {'created_at': '2023-05-11T22:17:49.226847',
#   'id': 'create:⟨e9914d6a-b7fb-40cd-aa01-4c4c6481ced3⟩',
#   'in': 'artist:⟨0a0f5e67-7036-4af3-9a52-26caee305319⟩',
#   'out': 'product:⟨5869b070-2805-4008-9997-38849975da4d⟩',
#   'quantity': 8},
#  {'created_at': '2023-07-22T18:22:17.075201',
#   'id': 'create:⟨49f994f0-bf32-45b4-9077-898d8d09e820⟩',
#   'in': 'artist:⟨a3ae22bb-08f3-4827-b675-8b8643fb3446⟩',
#   'out': 'product:⟨17fa7d0f-c9b3-4678-a5d8-8c17a2670e85⟩',
#   'quantity': 20},
#  {'created_at': '2023-05-30T06:17:36.569074',
#   'id': 'create:⟨8b98cf06-0597-47ae-943e-28a8b25313ef⟩',
#   'in': 'artist:⟨704adbee-d0fc-428a-be47-dc304e0b3cec⟩',
#   'out': 'product:⟨664eb8c7-d976-4b1a-b269-93b363e3311c⟩',
#   'quantity': 20},
#  {'created_at': '2023-03-31T09:03:23.181226',
#   'id': 'create:⟨9843f0ad-9596-46f5-ba13-40592f33a6eb⟩',
#   'in': 'artist:⟨991b6775-2aff-4db9-b31d-187d92736e2d⟩',
#   'out': 'product:⟨fa158076-e84e-4975-8d0f-d3f6a29927c5⟩',
#   'quantity': 7},
#  {'created_at': '2023-07-02T02:22:04.731474',
#   'id': 'create:⟨426293d0-af42-4fbe-8f39-41b2df2dade2⟩',
#   'in': 'artist:⟨ecf274a4-cd6d-42c0-b35b-35db589b2ea8⟩',
#   'out': 'product:⟨dc9a02f5-1330-47cf-86e7-dc66bbca91de⟩',
#   'quantity': 3},
#  {'created_at': '2023-07-18T04:50:56.937577',
#   'id': 'create:⟨43df7d03-8ece-423a-850f-90284a09e038⟩',
#   'in': 'artist:⟨5c59c203-0565-4576-b834-2100c8e0c46e⟩',
#   'out': 'product:⟨c819ea0e-7e78-402f-a71c-e660ffba8043⟩',
#   'quantity': 2},
#  {'created_at': '2023-05-02T07:55:10.971487',
#   'id': 'create:⟨2b2e655b-d4eb-458d-9da3-68c594da5b11⟩',
#   'in': 'artist:⟨075a5ba8-756c-4a4e-8832-c757ee35da70⟩',
#   'out': 'product:⟨122bc2b6-d5d0-4767-8d8c-0af6daae56b8⟩',
#   'quantity': 16},
#  {'created_at': '2023-03-19T08:19:27.157714',
#   'id': 'create:⟨341621bb-8683-4d1a-8a26-3a01c7758ad7⟩',
#   'in': 'artist:⟨6cccbdd1-6b21-495d-999e-8b4494d6d6cd⟩',
#   'out': 'product:⟨0a86b9bb-1857-4487-8132-b1a78d6eebe7⟩',
#   'quantity': 10},
#  {'created_at': '2023-09-25T12:34:37.010188',
#   'id': 'create:⟨6389c325-c1a5-4e0d-baf9-c119a78e41dd⟩',
#   'in': 'artist:⟨32dbcf64-c307-4c5a-baa8-74ffb529ad26⟩',
#   'out': 'product:⟨9a1f4d12-dfd3-4c15-b5a3-087b2b694246⟩',
#   'quantity': 13},
#  {'created_at': '2023-05-07T12:04:54.007954',
#   'id': 'create:⟨07c5e9b4-09c1-4e92-9057-cacc39ea3743⟩',
#   'in': 'artist:⟨ee59a880-ea24-4130-b613-6720c540bbdf⟩',
#   'out': 'product:⟨264b239a-e418-4344-b0e4-b75a8d7dda5c⟩',
#   'quantity': 7},
#  {'created_at': '2023-04-07T00:06:57.005128',
#   'id': 'create:⟨a5db4000-22cc-49e3-8fa8-83310e3bfc00⟩',
#   'in': 'artist:⟨4863d913-a9a9-4080-b262-b374029b9fbd⟩',
#   'out': 'product:⟨e8c9b861-9251-42f7-a5a7-5dd4dd06eee4⟩',
#   'quantity': 3},
#  {'created_at': '2023-08-18T01:16:17.726081',
#   'id': 'create:⟨3e3cb58c-06c4-4f91-b1c2-33e3e1de3d1e⟩',
#   'in': 'artist:⟨dae8011a-f387-45ab-8853-abbae0ec84d8⟩',
#   'out': 'product:⟨a0e971ec-1827-4cb1-9ad1-4e4cafe22624⟩',
#   'quantity': 9},
#  {'created_at': '2023-12-17T08:17:14.763285',
#   'id': 'create:⟨e9653cc3-611e-465a-b6a2-57cc1c9d2804⟩',
#   'in': 'artist:⟨080ce218-a103-42a0-85a8-be9cbbc9c004⟩',
#   'out': 'product:⟨de54080c-a0dd-47b9-a73d-3d81dcaacb6e⟩',
#   'quantity': 4},
#  {'created_at': '2023-04-09T19:27:45.400641',
#   'id': 'create:⟨9eac5d85-344d-4e5f-898d-648f93ab0f16⟩',
#   'in': 'artist:⟨f392b9f1-248f-46c8-9306-8c6f0207ab52⟩',
#   'out': 'product:⟨e83c93fe-906d-4c54-991d-9214f99065d9⟩',
#   'quantity': 18},
#  {'created_at': '2023-01-24T01:47:16.811628',
#   'id': 'create:⟨749f0414-2d18-4b07-bf12-3b50d622105a⟩',
#   'in': 'artist:⟨af9d8f6e-f527-4aed-a63b-61d293384605⟩',
#   'out': 'product:⟨bf18873e-62f2-4732-81fa-76fc414c849c⟩',
#   'quantity': 5},
#  {'created_at': '2023-04-16T11:41:44.351146',
#   'id': 'create:⟨23f49661-a9eb-4775-b102-be06dcb98bc7⟩',
#   'in': 'artist:⟨87ad1f18-8a07-42fd-a929-10f2884c8ce4⟩',
#   'out': 'product:⟨9c5987fa-f3b1-48de-9323-89e963041515⟩',
#   'quantity': 6},
#  {'created_at': '2023-06-27T17:37:27.721957',
#   'id': 'create:⟨2c5d144c-d459-4050-ac26-a8532682bf55⟩',
#   'in': 'artist:⟨0091d52b-9569-415c-9bab-9bc5dca7a470⟩',
#   'out': 'product:⟨e00a09bd-1b8d-4222-85ca-59feff184dd7⟩',
#   'quantity': 19},
#  {'created_at': '2023-06-22T21:00:54.856306',
#   'id': 'create:⟨20b12486-6f05-47df-b248-38ccb1c7baf2⟩',
#   'in': 'artist:⟨3df5a467-edc1-4b31-b903-8937029118d6⟩',
#   'out': 'product:⟨b3a93fa7-0b41-42ed-847b-283397ab53cd⟩',
#   'quantity': 2},
#  {'created_at': '2023-07-04T22:34:15.503485',
#   'id': 'create:⟨6530f59a-b1b7-4560-a84d-e3d0f84f3f81⟩',
#   'in': 'artist:⟨5cb48b91-21a2-45cc-9642-bf46f6fb6d8c⟩',
#   'out': 'product:⟨a24c6eaa-99da-4385-a0cf-ecce607f340f⟩',
#   'quantity': 3},
#  {'created_at': '2023-11-14T17:56:58.510928',
#   'id': 'create:⟨6a14dbc2-7493-4170-8acd-016906ba5d45⟩',
#   'in': 'artist:⟨1f93067b-4505-4376-830a-0c2dab86a09c⟩',
#   'out': 'product:⟨ea6f8a92-cbf6-4706-9702-006a26f873c8⟩',
#   'quantity': 13},
#  {'created_at': '2023-11-14T21:22:01.810846',
#   'id': 'create:⟨cb9783c9-0e6a-4cbf-97e1-6f6618a857fb⟩',
#   'in': 'artist:⟨225cc4cd-43f1-4c97-b1cf-e1ed0629f1a3⟩',
#   'out': 'product:⟨59bea3c5-63cd-4720-bde6-a6f6980976d6⟩',
#   'quantity': 7},
#  {'created_at': '2023-10-28T23:25:19.468924',
#   'id': 'create:⟨e4f07975-52f4-48c2-ba9a-79939ac41b0c⟩',
#   'in': 'artist:⟨74bfd06a-a807-4eda-b9e9-be1ce1734539⟩',
#   'out': 'product:⟨e3ae1c59-951f-4b0b-86b4-523349ddb1e2⟩',
#   'quantity': 7},
#  {'created_at': '2023-09-25T04:26:10.436509',
#   'id': 'create:⟨bd0e30c6-6899-4c05-ab51-6ead4550760b⟩',
#   'in': 'artist:⟨dae8011a-f387-45ab-8853-abbae0ec84d8⟩',
#   'out': 'product:⟨a929ae8e-8859-444f-a099-8b8445f735dc⟩',
#   'quantity': 19},
#  {'created_at': '2023-10-05T04:13:19.169246',
#   'id': 'create:⟨f17aee58-96f5-4162-b8f0-f747c80db6c0⟩',
#   'in': 'artist:⟨f3fb07a9-d9ed-4a11-9e74-5ee1e520532b⟩',
#   'out': 'product:⟨682ac8d9-f6ae-4b37-9174-6ad0466401e5⟩',
#   'quantity': 0},
#  {'created_at': '2023-05-27T06:16:26.774717',
#   'id': 'create:⟨e5f0249c-816e-4366-8134-7ac776649431⟩',
#   'in': 'artist:⟨cab87602-d79d-45eb-9f39-03e8b6000fe0⟩',
#   'out': 'product:⟨18aaad95-375c-446f-a4f7-d459461b2bc8⟩',
#   'quantity': 19},
#  {'created_at': '2023-11-13T03:37:20.931751',
#   'id': 'create:⟨8b3120db-60a5-4ff7-b8fb-6b7e98c44da7⟩',
#   'in': 'artist:⟨67580bc0-1971-4cef-a99a-94f56bd6c02c⟩',
#   'out': 'product:⟨16cf841d-12ff-411d-a111-467473ca8961⟩',
#   'quantity': 12},
#  {'created_at': '2023-02-08T22:22:09.251957',
#   'id': 'create:⟨2874c2e7-b86f-4a41-8737-51a93fe64f46⟩',
#   'in': 'artist:⟨bd0aa189-29e7-45bd-83c0-215173ce9786⟩',
#   'out': 'product:⟨40d05aa1-91fd-4c4f-868e-4066c6954d5c⟩',
#   'quantity': 7},
#  {'created_at': '2023-12-09T19:02:25.031307',
#   'id': 'create:⟨e13e3d4a-065f-4a40-9f71-8a95d4ceff16⟩',
#   'in': 'artist:⟨aaf63245-2fee-4551-b34e-359cd9aec8a2⟩',
#   'out': 'product:⟨316d6064-05ec-494f-8813-6ac146b807ce⟩',
#   'quantity': 7},
#  {'created_at': '2023-10-27T23:04:13.307069',
#   'id': 'create:⟨b12a3723-e441-41ff-b534-4e0a3aa8f768⟩',
#   'in': 'artist:⟨f735acb1-c1db-4a22-aca5-9688b7c50aec⟩',
#   'out': 'product:⟨d5f846f1-6223-4810-9601-a994979aa7cd⟩',
#   'quantity': 2},
#  {'created_at': '2023-07-10T16:27:14.706710',
#   'id': 'create:⟨61e4cf2b-fbf4-473a-bb37-25e0deae8b0a⟩',
#   'in': 'artist:⟨3fefdcc1-87ad-4a31-a185-134f0b74d7dc⟩',
#   'out': 'product:⟨835a327f-9a77-4215-9d88-2090ab39e385⟩',
#   'quantity': 0},
#  {'created_at': '2023-11-18T18:46:35.952046',
#   'id': 'create:⟨1d51301b-ebf7-4b16-b18c-f1c1d0d232a7⟩',
#   'in': 'artist:⟨61b51a50-3b21-4750-a780-66f24dfc602e⟩',
#   'out': 'product:⟨672a0dcf-1e3a-4a0a-9c48-5e617f7e0ea0⟩',
#   'quantity': 4},
#  {'created_at': '2023-02-10T13:45:35.661216',
#   'id': 'create:⟨3ff6b5a4-9a57-4965-a288-09b403d3af7e⟩',
#   'in': 'artist:⟨9bbd15ea-bf36-4fac-b79f-9df002c08893⟩',
#   'out': 'product:⟨ca6f10b1-d488-40c6-81e6-c696ba117187⟩',
#   'quantity': 18},
#  {'created_at': '2023-11-26T02:34:09.495326',
#   'id': 'create:⟨6b51ea82-3a36-4799-a3bd-575ec5584734⟩',
#   'in': 'artist:⟨e1663c08-5273-487e-bea5-b7a9f26f87ec⟩',
#   'out': 'product:⟨727d4a3a-f13a-4cfd-8a6e-7245f9e46561⟩',
#   'quantity': 5},
#  {'created_at': '2023-05-07T00:24:52.660068',
#   'id': 'create:⟨58458e63-c353-44d6-a4f6-de874958e117⟩',
#   'in': 'artist:⟨4f779011-88ea-42c2-acb7-20e271b7fe40⟩',
#   'out': 'product:⟨07886800-0774-4708-aaa1-1244a175ac14⟩',
#   'quantity': 2},
#  {'created_at': '2023-02-18T23:04:25.586899',
#   'id': 'create:⟨eb04d078-eace-4eb3-8d05-09e7ce54d55e⟩',
#   'in': 'artist:⟨e6919bda-1b46-4a29-afa9-c8127f1080d4⟩',
#   'out': 'product:⟨3ae2690c-94fe-4416-980d-6f30404d72fa⟩',
#   'quantity': 0},
#  {'created_at': '2023-06-16T00:35:09.868194',
#   'id': 'create:⟨b8c80fb5-1791-4a1d-8ee4-c81980744a7f⟩',
#   'in': 'artist:⟨3c37be2c-6594-44fc-a965-e68bfee12e37⟩',
#   'out': 'product:⟨faccf6a6-0153-4a32-b3e7-884831cdc526⟩',
#   'quantity': 1}]

# %% [markdown]
#  ## Run the queries

# %%
from random import randint
# getting just an array of ids to use for loops in some queries
person_ids = db.query(f"SELECT VALUE id FROM person")
product_ids = db.query(f"SELECT VALUE id FROM product")
order_ids = db.query(f"SELECT VALUE id FROM order")
artist_ids = db.query(f"SELECT VALUE id FROM artist")
review_ids = db.query(f"SELECT VALUE id FROM review")

# %% [markdown]
#  ### Q1: lookup vs record links

# %%
# %%timeit
list(db.query(""" 
SELECT
    id,
    rating,
    review_text,
	artist.name,
	artist.email,
	artist.phone,
	person.name,
	person.email,
	person.phone,
	product.name,
	product.category,
	product.price
FROM review;
"""))

# %% [markdown]
#  ### Q2: lookup vs graph

# %%
# %%timeit
db.query(""" 
SELECT
	price,
	order_date,
	product_name,
	->product.category,
	->product.description,
	->product.image_url,
	<-person.name,
	<-person.email,
	<-person.phone,
	->product<-create<-artist.name,
	->product<-create<-artist.email,
	->product<-create<-artist.phone
FROM order;
""")

# %% [markdown]
#  ### Q2: lookup vs graph - using in/out instead of arrow

# %%
# %%timeit
db.query(""" 
SELECT
	price,
	order_date,
	product_name,
	out.category,
	out.description,
	out.image_url,
	in.person.name,
	in.person.email,
	in.person.phone,
	out<-create.in.name,
	out<-create.in.email,
	out<-create.in.phone
FROM order;
""")

# %% [markdown]
#  ### Q3: Name and email for all customers in England

# %%
# %%time
db.query(""" 
DEFINE INDEX person_country ON TABLE person COLUMNS address.country;
""")

# %%
# %%timeit
db.query(""" 
SELECT name, email 
FROM person 
WHERE address.country = "England";	
""")

# %% [markdown]
#  ### Q4: Count the number of confirmed orders in Q1 by artists in England

# %%
# %%timeit
db.query(""" 
SELECT count() FROM order
WHERE (order_status != "pending"
OR order_status = null)
AND time::month(<datetime>order_date) <=3
AND ->product<-create<-artist.address.country ?= "England"
GROUP ALL;
""")

# %% [markdown]
#  ### Q5: Delete a specific review

# %%
# %%time
db.query(f""" 
DELETE {review_ids[0]};
""")

# %% [markdown]
#  ### Q6: Delete reviews from a particular category

# %%
# %%time
db.query(""" 
DELETE review
WHERE product.category = "charcoal";
""")

# %% [markdown]
#  ### Q7: Update a customer address

# %%
# %%timeit
db.query(f"UPDATE {person_ids[randint(0, person_id_count)]}"+"""
SET address = {
	'address_line_1': '497 Ballycander',
	'address_line_2': None,
	'city': 'Bromyard',
	'country': 'Wales',
	'post_code': 'ZX8N 4VJ',
	'coordinates': [68.772592, -35.491877]
	}
RETURN NONE;
""")

# %% [markdown]
#  ### Q8: Update discounts for products

# %%
# %%time
db.query(""" 
UPDATE product
SET discount = 0.2
WHERE price < 1000
RETURN NONE;
""")

# %% [markdown]
#  ### Q9: Transaction - order from a new customer

# %%
# %%timeit
random_person_id = person_ids[randint(0, person_id_count)]
random_product_id = product_ids[randint(0, product_id_count)]

db.query(""" 
# Transaction - order from a new customer
BEGIN TRANSACTION;
-- insert into the person table
CREATE person CONTENT {
	"""+f"'id': {random_person_id},"+"""
	'first_name': 'Karyl',
	'last_name': 'Langley',
	'name': 'Karyl Langley',
	'company_name': None,
	'email': 'dee1961@gmail.com',
	'phone': '+44 47 3516 5895',
	'address': {
		'address_line_1': '510 Henalta',
		'address_line_2': None,
		'city': 'Lyme Regis',
		'country': 'Northern Ireland',
		'post_code': 'TO6Q 8CM',
		'coordinates': [-34.345071, 118.564172]
		}
	};

-- relate into the order table"""+
f"RELATE {random_person_id} -> order:uuid() -> {random_product_id}"+"""
CONTENT {
        "currency": "£",
        "discount": ->product.discount,
        "order_date": time::now(),
        "order_status": "pending",
        "payment_method": "PayPal",
        "price": ->product.price,
        "product_name": ->product.name,
        "quantity": 1,
        "shipping_address": <-person.address
	};

-- update the product table to reduce the quantity"""+
f"""
UPDATE {random_product_id} SET quantity -= 1 RETURN NONE;
COMMIT TRANSACTION;
""")

# %% [markdown]
#  ### Q10: "Transaction"* - New Artist creates their first product

# %%
# %%timeit
# Transaction - New Artist creates their first product

new_artist_id = str(uuid4())
new_product_id = str(uuid4())

db.query(""" 
BEGIN TRANSACTION;
-- insert into the artist table
CREATE artist CONTENT {"""+
        f"'id': 'artist:⟨{new_artist_id}⟩',"+"""
        'first_name': 'Anderson',
        'last_name': 'West',
        'name': 'Anderson West',
        'company_name': 'Atkins(ws) (ATK)',
        'email': 'six1933@gmail.com',
        'phone': '056 5881 1126',
        'address': {
                'address_line_1': '639 Connaugh',
                'address_line_2': None,
                'city': 'Ripon',
                'country': 'Scotland',
                'post_code': 'CG3U 4TH',
                'coordinates': [4.273648, -112.907273]
                }
        };

-- insert into the product table
CREATE product CONTENT {"""+
        f"'id': 'product:⟨{new_product_id}⟩',"+"""
        'name': 'managed edt allocated pda',
        'description': 'counseling dildo greek pan works interest xhtml wrong dennis available cl specific next tower webcam peace magic',
        'category': 'watercolor',
        'price': 15735.96,
        'currency': '£',
        'discount': None,
        'quantity': 1,
        'image_url': 'https://source.unsplash.com/1920x1080?'
        };

-- relate into the create table"""+
f"RELATE artist:⟨{new_artist_id}⟩ -> create:uuid() -> product:⟨{new_product_id}⟩"+"""
CONTENT {
        created_at: time::now(),
        quantity: 1
};
COMMIT TRANSACTION;
""")
